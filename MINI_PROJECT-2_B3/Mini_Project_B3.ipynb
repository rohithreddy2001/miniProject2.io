# %%
from bs4 import BeautifulSoup as soup
from datetime import date, datetime
from urllib.request import Request, urlopen

import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
import plotly.offline as py
import seaborn as sns
import gc
import warnings
warnings.filterwarnings("ignore")

from pandas_profiling import ProfileReport

# %% [markdown]
# **WEB SCRAPPING**

# %%
today = datetime.now()
yesterday_str = "%s %d,%d" %(date.today().strftime("%b"), today.day-1, today. year)
yesterday_str
# Out:
# 'Nov 20,2022'

# %%
url = "https://www.worldometers.info/coronavirus/#countries"
req = Request(url , headers={'user-Agent' : "Mozilla/5.0"})
webpage = urlopen(req)
page_soup = soup(webpage, "html.parser")

# %%
table = page_soup.findAll("table",{"id": "main_table_countries_yesterday"})

containers = table[0].findAll("tr",{"style":""})
title = containers[0]

del containers[0]

all_data = []
clean = True

for country in containers:
    country_data = []
    country_container = country.findAll("td")

    if country_container[1].text == "China":
        continue
    for i in range(1, len(country_container)):
        final_feature = country_container[i].text
        if clean:
            if i != 1 and i != len(country_container)-1:
                final_feature = final_feature.replace(",","")

                if final_feature.find('+') != -1:
                    final_feature = final_feature.replace("+","")
                    final_feature = float(final_feature)
                elif final_feature.find("-") != -1:
                    final_feature = final_feature.replace("-","")
                    final_feature = float(final_feature)*-1
        if final_feature == 'N/A':
            final_feature = 0
        elif final_feature == "" or final_feature == " ":
            final_feature = -1
        country_data.append(final_feature)
    all_data.append(country_data)

# %%
all_data
# Out:
# [['World',
#   '643105643',
#   209901.0,
#   '6626087',
#   396.0,
#   '622217754',
#   193233.0,
#   '14261802',
#   '36119',
#   '82504',
#   '850.1',
#   -1,
#   -1,
#   -1,
#   'All',
#   '\n',
#   -1,
#   -1,
#   -1,
#   -1,
#   -1],
#  ['USA',
#   '100209101',
#   4996.0,
#   '1102668                                ',
#   2.0,
#   '97751014',
#   18915.0,
#   '1355419',
#   '2745',
#   '299306',
#   '3293',
#   '1137483003',
#   '3397447',
#   '334805269 ',
#   'North America',
#   '3',
#   '304',
#   '0',
#   '15',
#   '0.01',
#   '4,048'],
#  ['India',
#   '44670438',
#   421.0,
#   '530586                                ',
#   12.0,
#   '44132433',
#   481.0,
#   '7419',
#   '698',
#   '31757',
#   '377',
#   '903809991',
#   '642535',
#   '1406631776 ',
#   'Asia',
#   '31',
#   '2651',
#   '2',
#   '0.3',
#   '0.01',
#   '5'],
#  ['France',
#   '37348839',
#   14204.0,
#   '158163                                ',
#   -1,
#   '36655222',
#   3768.0,
#   '535454',
#   '869',
#   '569476',
#   '2412',
#   '271490188',
#   '4139547',
#   '65584518 ',
#   'Europe',
#   '2',
#   '415',
#   '0',
#   '217',
#   -1,
#   '8,164'],
#  ['Germany',
#   '36205405',
#   -1,
#   '156613                                ',
#   -1,
#   '35359000',
#   11600.0,
#   '689792',
#   '1406',
#   '431615',
#   '1867',
#   '122332384',
#   '1458359',
#   '83883596 ',
#   'Europe',
#   '2',
#   '536',
#   '1',
#   -1,
#   -1,
#   '8,223'],
#  ['Brazil',
#   '35064320',
#   4300.0,
#   '689003                                ',
#   9.0,
#   '34167667',
#   -1,
#   '207650',
#   '8318',
#   '162822',
#   '3199',
#   '63776166',
#   '296146',
#   '215353593 ',
#   'South America',
#   '6',
#   '313',
#   '3',
#   '20',
#   '0.04',
#   '964'],
#  ['S. Korea',
#   '26558765',
#   46011.0,
#   '30031                                ',
#   41.0,
#   '25640417',
#   54675.0,
#   '888317',
#   '451',
#   '517413',
#   '585',
#   '15804065',
#   '307892',
#   '51329899 ',
#   'Asia',
#   '2',
#   '1709',
#   '3',
#   '896',
#   '0.8',
#   '17,306'],
#  ['Italy',
#   '24031538',
#   -1,
#   '180518                                ',
#   -1,
#   '23398125',
#   -1,
#   '452895',
#   '247',
#   '398779',
#   '2996',
#   '255780377',
#   '4244418',
#   '60262770 ',
#   'Europe',
#   '3',
#   '334',
#   '0',
#   -1,
#   -1,
#   '7,515'],
#  ['UK',
#   '23977637',
#   -1,
#   '196241                                ',
#   -1,
#   '23689565',
#   4932.0,
#   '91831',
#   '146',
#   '350049',
#   '2865',
#   '522526476',
#   '7628357',
#   '68497907 ',
#   'Europe',
#   '3',
#   '349',
#   '0',
#   -1,
#   -1,
#   '1,341'],
#  ['Japan',
#   '23771785',
#   77722.0,
#   '48281                                ',
#   122.0,
#   '20613752',
#   6789.0,
#   '3109752',
#   '262',
#   '189289',
#   '384',
#   '79720829',
#   '634797',
#   '125584838 ',
#   'Asia',
#   '5',
#   '2601',
#   '2',
#   '619',
#   '1.0',
#   '24,762'],
#  ['Russia',
#   '21536229',
#   5217.0,
#   '391454                                ',
#   59.0,
#   '20943924',
#   4443.0,
#   '200851',
#   '2300',
#   '147705',
#   '2685',
#   '273400000',
#   '1875095',
#   '145805947 ',
#   'Europe',
#   '7',
#   '372',
#   '1',
#   '36',
#   '0.4',
#   '1,378'],
#  ['Spain',
#   '13573721',
#   -1,
#   '115641                                ',
#   -1,
#   '13357848',
#   -1,
#   '100232',
#   '339',
#   '290539',
#   '2475',
#   '471036328',
#   '10082298',
#   '46719142 ',
#   'Europe',
#   '3',
#   '404',
#   '0',
#   -1,
#   -1,
#   '2,145'],
#  ['Vietnam',
#   '11511452',
#   274.0,
#   '43169                                ',
#   -1,
#   '10606901',
#   155.0,
#   '861382',
#   '107',
#   '116332',
#   '436',
#   '85826548',
#   '867342',
#   '98953541 ',
#   'Asia',
#   '9',
#   '2292',
#   '1',
#   '3',
#   -1,
#   '8,705'],
#  ['Australia',
#   '10557719',
#   2407.0,
#   '15980                                ',
#   -1,
#   '10364130',
#   -1,
#   '177609',
#   '67',
#   '404995',
#   '613',
#   '78835048',
#   '3024116',
#   '26068792 ',
#   'Australia/Oceania',
#   '2',
#   '1631',
#   '0',
#   '92',
#   -1,
#   '6,813'],
#  ['Argentina',
#   '9723924',
#   2206.0,
#   '130017                                ',
#   6.0,
#   '9587535',
#   -1,
#   '6372',
#   '237',
#   '211343',
#   '2826',
#   '35716069',
#   '776264',
#   '46010234 ',
#   'South America',
#   '5',
#   '354',
#   '1',
#   '48',
#   '0.1',
#   '138'],
#  ['Netherlands',
#   '8534144',
#   -1,
#   '22892                                ',
#   -1,
#   '8470861',
#   2684.0,
#   '40391',
#   '37',
#   '495841',
#   '1330',
#   '25984435',
#   '1509718',
#   '17211447 ',
#   'Europe',
#   '2',
#   '752',
#   '1',
#   -1,
#   -1,
#   '2,347'],
#  ['Taiwan',
#   '8162988',
#   16216.0,
#   '13950                                ',
#   43.0,
#   '7698788',
#   22544.0,
#   '450250',
#   -1,
#   '341711',
#   '584',
#   '28313097',
#   '1185214',
#   '23888595 ',
#   'Asia',
#   '3',
#   '1712',
#   '1',
#   '679',
#   '2',
#   '18,848'],
#  ['Iran',
#   '7559296',
#   38.0,
#   '144626                                ',
#   1.0,
#   '7334732',
#   71.0,
#   '79938',
#   '80',
#   '87875',
#   '1681',
#   '54420785',
#   '632632',
#   '86022837 ',
#   'Asia',
#   '11',
#   '595',
#   '2',
#   '0.4',
#   '0.01',
#   '929'],
#  ['Mexico',
#   '7118933',
#   -1,
#   '330444                                ',
#   -1,
#   '6390444',
#   -1,
#   '398045',
#   '4798',
#   '54111',
#   '2512',
#   '18675146',
#   '141949',
#   '131562772 ',
#   'North America',
#   '18',
#   '398',
#   '7',
#   -1,
#   -1,
#   '3,026'],
#  ['Indonesia',
#   '6608367',
#   5172.0,
#   '159379                                ',
#   31.0,
#   '6386809',
#   5690.0,
#   '62179',
#   '2771',
#   '23674',
#   '571',
#   '111772509',
#   '400425',
#   '279134505 ',
#   'Asia',
#   '42',
#   '1751',
#   '2',
#   '19',
#   '0.1',
#   '223'],
#  ['Poland',
#   '6348842',
#   71.0,
#   '118274                                ',
#   -1,
#   '5335940',
#   -1,
#   '894628',
#   '1530',
#   '168227',
#   '3134',
#   '37743088',
#   '1000088',
#   '37739785 ',
#   'Europe',
#   '6',
#   '319',
#   '1',
#   '2',
#   -1,
#   '23,705'],
#  ['Colombia',
#   '6312657',
#   -1,
#   '141881                                ',
#   -1,
#   '6139728',
#   -1,
#   '31048',
#   '342',
#   '122545',
#   '2754',
#   '36831583',
#   '714999',
#   '51512762 ',
#   'South America',
#   '8',
#   '363',
#   '1',
#   -1,
#   -1,
#   '603'],
#  ['Portugal',
#   '5537108',
#   -1,
#   '25395                                ',
#   -1,
#   '5489221',
#   1043.0,
#   '22492',
#   '61',
#   '546035',
#   '2504',
#   '45059939',
#   '4443531',
#   '10140570 ',
#   'Europe',
#   '2',
#   '399',
#   '0',
#   -1,
#   -1,
#   '2,218'],
#  ['Austria',
#   '5517893',
#   2999.0,
#   '21144                                ',
#   -1,
#   '5457225',
#   2683.0,
#   '39524',
#   '47',
#   '608588',
#   '2332',
#   '202088800',
#   '22289099',
#   '9066710 ',
#   'Europe',
#   '2',
#   '429',
#   '0',
#   '331',
#   -1,
#   '4,359'],
#  ['Ukraine',
#   '5329536',
#   -1,
#   '110403                                ',
#   -1,
#   '5195211',
#   2340.0,
#   '23922',
#   -1,
#   '123391',
#   '2556',
#   '32603805',
#   '754855',
#   '43192122 ',
#   'Europe',
#   '8',
#   '391',
#   '1',
#   -1,
#   -1,
#   '554'],
#  ['Greece',
#   '5306482',
#   -1,
#   '34024                                ',
#   -1,
#   '5224291',
#   8027.0,
#   '48167',
#   '115',
#   '514362',
#   '3298',
#   '98962476',
#   '9592513',
#   '10316637 ',
#   'Europe',
#   '2',
#   '303',
#   '0',
#   -1,
#   -1,
#   '4,669'],
#  ['Malaysia',
#   '4967299',
#   1633.0,
#   '36595                                ',
#   2.0,
#   '4903906',
#   1989.0,
#   '26798',
#   '94',
#   '149703',
#   '1103',
#   '66123579',
#   '1992810',
#   '33181072 ',
#   'Asia',
#   '7',
#   '907',
#   '1',
#   '49',
#   '0.06',
#   '808'],
#  ['Chile',
#   '4877248',
#   5397.0,
#   '62187                                ',
#   22.0,
#   '4798844',
#   7735.0,
#   '16217',
#   '138',
#   '253361',
#   '3230',
#   '46801026',
#   '2431198',
#   '19250195 ',
#   'South America',
#   '4',
#   '310',
#   '0',
#   '280',
#   '1',
#   '842'],
#  ['Israel',
#   '4705787',
#   643.0,
#   '11810                                ',
#   -1,
#   '4685301',
#   1448.0,
#   '8676',
#   '36',
#   '504588',
#   '1266',
#   '41373364',
#   '4436346',
#   '9326000 ',
#   'Asia',
#   '2',
#   '790',
#   '0',
#   '69',
#   -1,
#   '930'],
#  ['Thailand',
#   '4698373',
#   -1,
#   '33037                                ',
#   -1,
#   '4649509',
#   -1,
#   '15827',
#   '1496',
#   '67045',
#   '471',
#   '17270775',
#   '246450',
#   '70078203 ',
#   'Asia',
#   '15',
#   '2121',
#   '4',
#   -1,
#   -1,
#   '226'],
#  ['Belgium',
#   '4627186',
#   -1,
#   '33021                                ',
#   -1,
#   '4569417',
#   2700.0,
#   '24748',
#   '57',
#   '396561',
#   '2830',
#   '36044419',
#   '3089095',
#   '11668278 ',
#   'Europe',
#   '3',
#   '353',
#   '0',
#   -1,
#   -1,
#   '2,121'],
#  ['Canada',
#   '4377070',
#   -1,
#   '47118                                ',
#   -1,
#   '4270763',
#   3163.0,
#   '59189',
#   '99',
#   '114021',
#   '1227',
#   '66043555',
#   '1720403',
#   '38388419 ',
#   'North America',
#   '9',
#   '815',
#   '1',
#   -1,
#   -1,
#   '1,542'],
#  ['Switzerland',
#   '4276830',
#   -1,
#   '14290                                ',
#   -1,
#   '4180603',
#   5258.0,
#   '81937',
#   '59',
#   '487464',
#   '1629',
#   '22861905',
#   '2605750',
#   '8773637 ',
#   'Europe',
#   '2',
#   '614',
#   '0',
#   -1,
#   -1,
#   '9,339'],
#  ['Peru',
#   '4188692',
#   -1,
#   '217241                                ',
#   -1,
#   '3944388',
#   -1,
#   '27063',
#   '54',
#   '124352',
#   '6449',
#   '36158138',
#   '1073445',
#   '33684208 ',
#   'South America',
#   '8',
#   '155',
#   '1',
#   -1,
#   -1,
#   '803'],
#  ['Czechia',
#   '4167937',
#   119.0,
#   '41757                                ',
#   2.0,
#   '4123765',
#   610.0,
#   '2415',
#   '16',
#   '388192',
#   '3889',
#   '56565985',
#   '5268429',
#   '10736784 ',
#   'Europe',
#   '3',
#   '257',
#   '0',
#   '11',
#   '0.2',
#   '225'],
#  ['South Africa',
#   '4037221',
#   -1,
#   '102371                                ',
#   -1,
#   '3912506',
#   -1,
#   '22344',
#   '192',
#   '66450',
#   '1685',
#   '26473049',
#   '435726',
#   '60756135 ',
#   'Africa',
#   '15',
#   '593',
#   '2',
#   -1,
#   -1,
#   '368'],
#  ['Philippines',
#   '4025957',
#   1103.0,
#   '64476                                ',
#   8.0,
#   '3942794',
#   1170.0,
#   '18687',
#   '155',
#   '35783',
#   '573',
#   '33549373',
#   '298193',
#   '112508994 ',
#   'Asia',
#   '28',
#   '1745',
#   '3',
#   '10',
#   '0.07',
#   '166'],
#  ['Romania',
#   '3294232',
#   167.0,
#   '67253                                ',
#   -1,
#   '3221751',
#   316.0,
#   '5228',
#   '95',
#   '173095',
#   '3534',
#   '25678733',
#   '1349287',
#   '19031335 ',
#   'Europe',
#   '6',
#   '283',
#   '1',
#   '9',
#   -1,
#   '275'],
#  ['Denmark',
#   '3143261',
#   -1,
#   '7470                                ',
#   -1,
#   '3131280',
#   -1,
#   '4511',
#   '1',
#   '538695',
#   '1280',
#   '128747914',
#   '22064956',
#   '5834950 ',
#   'Europe',
#   '2',
#   '781',
#   '0',
#   -1,
#   -1,
#   '773'],
#  ['Sweden',
#   '2622790',
#   -1,
#   '20896                                ',
#   -1,
#   '2588428',
#   487.0,
#   '13466',
#   '18',
#   '256659',
#   '2045',
#   '19112603',
#   '1870306',
#   '10218971 ',
#   'Europe',
#   '4',
#   '489',
#   '1',
#   -1,
#   -1,
#   '1,318'],
#  ['Iraq',
#   '2462317',
#   -1,
#   '25361                                ',
#   -1,
#   '2436308',
#   -1,
#   '648',
#   '21',
#   '58397',
#   '601',
#   '19424126',
#   '460670',
#   '42164965 ',
#   'Asia',
#   '17',
#   '1663',
#   '2',
#   -1,
#   -1,
#   '15'],
#  ['Serbia',
#   '2417633',
#   363.0,
#   '17344                                ',
#   1.0,
#   '2388659',
#   849.0,
#   '11630',
#   '16',
#   '279398',
#   '2004',
#   '11541093',
#   '1333765',
#   '8653016 ',
#   'Europe',
#   '4',
#   '499',
#   '1',
#   '42',
#   '0.1',
#   '1,344'],
#  ['Hungary',
#   '2157995',
#   -1,
#   '48184                                ',
#   -1,
#   '2091278',
#   -1,
#   '18533',
#   '10',
#   '224645',
#   '5016',
#   '11394556',
#   '1186160',
#   '9606259 ',
#   'Europe',
#   '4',
#   '199',
#   '1',
#   -1,
#   -1,
#   '1,929'],
#  ['Singapore',
#   '2153535',
#   1167.0,
#   '1700                                ',
#   1.0,
#   '2076837',
#   2041.0,
#   '74998',
#   '8',
#   '362332',
#   '286',
#   '24622510',
#   '4142731',
#   '5943546 ',
#   'Asia',
#   '3',
#   '3496',
#   '0',
#   '196',
#   '0.2',
#   '12,618'],
#  ['Hong Kong',
#   '2036681',
#   7736.0,
#   '10599                                ',
#   13.0,
#   '1821698',
#   5415.0,
#   '204384',
#   '12',
#   '267833',
#   '1394',
#   '66284763',
#   '8716749',
#   '7604299 ',
#   'Asia',
#   '4',
#   '717',
#   '0',
#   '1017',
#   '2',
#   '26,877'],
#  ['Bangladesh',
#   '2036367',
#   24.0,
#   '29430                                ',
#   -1,
#   '1984797',
#   193.0,
#   '22140',
#   '1331',
#   '12129',
#   '175',
#   '15063346',
#   '89724',
#   '167885689 ',
#   'Asia',
#   '82',
#   '5705',
#   '11',
#   '0.1',
#   -1,
#   '132'],
#  ['New Zealand',
#   '1914636',
#   3435.0,
#   '3233                                ',
#   5.0,
#   '1888777',
#   3076.0,
#   '22626',
#   -1,
#   '390885',
#   '660',
#   '7544063',
#   '1540170',
#   '4898203 ',
#   'Australia/Oceania',
#   '3',
#   '1515',
#   '1',
#   '701',
#   '1',
#   '4,619'],
#  ['Slovakia',
#   '1854999',
#   59.0,
#   '20711                                ',
#   2.0,
#   '1832840',
#   79.0,
#   '1448',
#   '34',
#   '339731',
#   '3793',
#   '7347645',
#   '1345675',
#   '5460193 ',
#   'Europe',
#   '3',
#   '264',
#   '1',
#   '11',
#   '0.4',
#   '265'],
#  ['Georgia',
#   '1785138',
#   -1,
#   '16912                                ',
#   -1,
#   '1637293',
#   -1,
#   '130933',
#   -1,
#   '449800',
#   '4261',
#   '16920079',
#   '4263340',
#   '3968738 ',
#   'Asia',
#   '2',
#   '235',
#   '0',
#   -1,
#   -1,
#   '32,991'],
#  ['Jordan',
#   '1746997',
#   -1,
#   '14122                                ',
#   -1,
#   '1731007',
#   -1,
#   '1868',
#   '59',
#   '169597',
#   '1371',
#   '17201885',
#   '1669945',
#   '10300869 ',
#   'Asia',
#   '6',
#   '729',
#   '1',
#   -1,
#   -1,
#   '181'],
#  ['Ireland',
#   '1677386',
#   -1,
#   '8102                                ',
#   -1,
#   '1663230',
#   -1,
#   '6054',
#   '7',
#   '334127',
#   '1614',
#   '12822657',
#   '2554213',
#   '5020199 ',
#   'Europe',
#   '3',
#   '620',
#   '0',
#   -1,
#   -1,
#   '1,206'],
#  ['Pakistan',
#   '1574897',
#   29.0,
#   '30630                                ',
#   -1,
#   '1538689',
#   -1,
#   '5578',
#   '42',
#   '6863',
#   '133',
#   '30570862',
#   '133213',
#   '229488994 ',
#   'Asia',
#   '146',
#   '7492',
#   '8',
#   '0.1',
#   -1,
#   '24'],
#  ['Norway',
#   '1467455',
#   53.0,
#   '4325                                ',
#   -1,
#   '1461198',
#   125.0,
#   '1932',
#   '20',
#   '266260',
#   '785',
#   '11002430',
#   '1996315',
#   '5511370 ',
#   'Europe',
#   '4',
#   '1274',
#   '1',
#   '10',
#   -1,
#   '351'],
#  ['Kazakhstan',
#   '1395763',
#   64.0,
#   '13693                                ',
#   -1,
#   '1380356',
#   -1,
#   '1714',
#   '24',
#   '72677',
#   '713',
#   '11575012',
#   '602707',
#   '19205043 ',
#   'Asia',
#   '14',
#   '1403',
#   '2',
#   '3',
#   -1,
#   '89'],
#  ['Finland',
#   '1384654',
#   -1,
#   '7173                                ',
#   -1,
#   '1342988',
#   2079.0,
#   '34493',
#   '21',
#   '249264',
#   '1291',
#   '11756851',
#   '2116460',
#   '5554960 ',
#   'Europe',
#   '4',
#   '774',
#   '0',
#   -1,
#   -1,
#   '6,209'],
#  ['Bulgaria',
#   '1285248',
#   51.0,
#   '37997                                ',
#   -1,
#   '1239637',
#   15.0,
#   '7614',
#   '55',
#   '187776',
#   '5551',
#   '10784616',
#   '1575639',
#   '6844597 ',
#   'Europe',
#   '5',
#   '180',
#   '1',
#   '7',
#   -1,
#   '1,112'],
#  ['Lithuania',
#   '1273039',
#   25.0,
#   '9418                                ',
#   3.0,
#   '1258660',
#   41.0,
#   '4961',
#   '7',
#   '478279',
#   '3538',
#   '10244553',
#   '3848864',
#   '2661708 ',
#   'Europe',
#   '2',
#   '283',
#   '0',
#   '9',
#   '1',
#   '1,864'],
#  ['Morocco',
#   '1267315',
#   49.0,
#   '16283                                ',
#   -1,
#   '1250221',
#   109.0,
#   '811',
#   '293',
#   '33551',
#   '431',
#   '12722902',
#   '336827',
#   '37772756 ',
#   'Africa',
#   '30',
#   '2320',
#   '3',
#   '1',
#   -1,
#   '21'],
#  ['Croatia',
#   '1251415',
#   190.0,
#   '17263                                ',
#   3.0,
#   '1232627',
#   208.0,
#   '1525',
#   '7',
#   '308285',
#   '4253',
#   '5342621',
#   '1316148',
#   '4059286 ',
#   'Europe',
#   '3',
#   '235',
#   '1',
#   '47',
#   '0.7',
#   '376'],
#  ['Slovenia',
#   '1247664',
#   292.0,
#   '6909                                ',
#   -1,
#   '1230806',
#   -1,
#   '9949',
#   '20',
#   '600406',
#   '3325',
#   '2778886',
#   '1337267',
#   '2078034 ',
#   'Europe',
#   '2',
#   '301',
#   '1',
#   '141',
#   -1,
#   '4,788'],
#  ['Lebanon',
#   '1220043',
#   50.0,
#   '10727                                ',
#   1.0,
#   '1087587',
#   -1,
#   '121729',
#   '74',
#   '182509',
#   '1605',
#   '4795578',
#   '717380',
#   '6684849 ',
#   'Asia',
#   '5',
#   '623',
#   '1',
#   '7',
#   '0.1',
#   '18,210'],
#  ['Guatemala',
#   '1148436',
#   183.0,
#   '19938                                ',
#   1.0,
#   '1126436',
#   157.0,
#   '2062',
#   '5',
#   '61797',
#   '1073',
#   '6225995',
#   '335018',
#   '18584039 ',
#   'North America',
#   '16',
#   '932',
#   '3',
#   '10',
#   '0.05',
#   '111'],
#  ['Tunisia',
#   '1146799',
#   -1,
#   '29266                                ',
#   -1,
#   0,
#   0,
#   0,
#   '44',
#   '95196',
#   '2429',
#   '4971787',
#   '412711',
#   '12046656 ',
#   'Africa',
#   '11',
#   '412',
#   '2',
#   -1,
#   -1,
#   '625'],
#  ['Costa Rica',
#   '1143597',
#   -1,
#   '9031                                ',
#   -1,
#   '860711',
#   -1,
#   '273855',
#   '52',
#   '220671',
#   '1743',
#   '4659757',
#   '899158',
#   '5182354 ',
#   'North America',
#   '5',
#   '574',
#   '1',
#   -1,
#   -1,
#   '52,844'],
#  ['Cuba',
#   '1111338',
#   1.0,
#   '8530                                ',
#   -1,
#   '1102741',
#   5.0,
#   '67',
#   -1,
#   '98299',
#   '754',
#   '14184566',
#   '1254644',
#   '11305652 ',
#   'North America',
#   '10',
#   '1325',
#   '1',
#   '0.09',
#   -1,
#   '6'],
#  ['Bolivia',
#   '1110170',
#   50.0,
#   '22244                                ',
#   -1,
#   '1076451',
#   159.0,
#   '11475',
#   '220',
#   '92571',
#   '1855',
#   '2705422',
#   '225590',
#   '11992656 ',
#   'South America',
#   '11',
#   '539',
#   '4',
#   '4',
#   -1,
#   '957'],
#  ['UAE',
#   '1042573',
#   233.0,
#   '2348                                ',
#   -1,
#   '1021686',
#   219.0,
#   '18539',
#   -1,
#   '103412',
#   '233',
#   '196638406',
#   '19504324',
#   '10081785 ',
#   'Asia',
#   '10',
#   '4294',
#   '0',
#   '23',
#   -1,
#   '1,839'],
#  ['Ecuador',
#   '1009388',
#   -1,
#   '35935                                ',
#   -1,
#   '973010',
#   284.0,
#   '443',
#   '759',
#   '55726',
#   '1984',
#   '3082403',
#   '170173',
#   '18113361 ',
#   'South America',
#   '18',
#   '504',
#   '6',
#   -1,
#   -1,
#   '24'],
#  ['Nepal',
#   '1000851',
#   2.0,
#   '12019                                ',
#   -1,
#   '988412',
#   14.0,
#   '420',
#   -1,
#   '33113',
#   '398',
#   '5972376',
#   '197593',
#   '30225582 ',
#   'Asia',
#   '30',
#   '2515',
#   '5',
#   '0.07',
#   -1,
#   '14'],
#  ['Belarus',
#   '994037',
#   -1,
#   '7118                                ',
#   -1,
#   '985592',
#   -1,
#   '1327',
#   -1,
#   '105381',
#   '755',
#   '13646641',
#   '1446722',
#   '9432800 ',
#   'Europe',
#   '9',
#   '1325',
#   '1',
#   -1,
#   -1,
#   '141'],
#  ['Panama',
#   '992623',
#   -1,
#   '8515                                ',
#   -1,
#   '982514',
#   -1,
#   '1594',
#   '16',
#   '223214',
#   '1915',
#   '7196883',
#   '1618381',
#   '4446964 ',
#   'North America',
#   '4',
#   '522',
#   '1',
#   -1,
#   -1,
#   '358'],
#  ['Uruguay',
#   '992035',
#   -1,
#   '7529                                ',
#   -1,
#   '983697',
#   -1,
#   '809',
#   '18',
#   '283762',
#   '2154',
#   '6114822',
#   '1749083',
#   '3496016 ',
#   'South America',
#   '4',
#   '464',
#   '1',
#   -1,
#   -1,
#   '231'],
#  ['Mongolia',
#   '989320',
#   -1,
#   '2179                                ',
#   -1,
#   '983266',
#   -1,
#   '3875',
#   '192',
#   '292865',
#   '645',
#   '4030048',
#   '1193000',
#   '3378078 ',
#   'Asia',
#   '3',
#   '1550',
#   '1',
#   -1,
#   -1,
#   '1,147'],
#  ['Latvia',
#   '959729',
#   710.0,
#   '6083                                ',
#   -1,
#   '947777',
#   -1,
#   '5869',
#   '3',
#   '519099',
#   '3290',
#   '7746372',
#   '4189862',
#   '1848837 ',
#   'Europe',
#   '2',
#   '304',
#   '0',
#   '384',
#   -1,
#   '3,174'],
#  ['Saudi Arabia',
#   '825087',
#   58.0,
#   '9447                                ',
#   1.0,
#   '812391',
#   79.0,
#   '3249',
#   '63',
#   '23018',
#   '264',
#   '44766876',
#   '1248905',
#   '35844909 ',
#   'Asia',
#   '43',
#   '3794',
#   '1',
#   '2',
#   '0.03',
#   '91'],
#  ['Azerbaijan',
#   '823954',
#   31.0,
#   '9972                                ',
#   -1,
#   '813750',
#   29.0,
#   '232',
#   -1,
#   '79994',
#   '968',
#   '7356956',
#   '714253',
#   '10300205 ',
#   'Asia',
#   '13',
#   '1033',
#   '1',
#   '3',
#   -1,
#   '23'],
#  ['Paraguay',
#   '718071',
#   -1,
#   '19611                                ',
#   -1,
#   '698317',
#   -1,
#   '143',
#   '7',
#   '98287',
#   '2684',
#   '2657506',
#   '363751',
#   '7305843 ',
#   'South America',
#   '10',
#   '373',
#   '3',
#   -1,
#   -1,
#   '20'],
#  ['Bahrain',
#   '694955',
#   215.0,
#   '1534                                ',
#   1.0,
#   '691793',
#   242.0,
#   '1628',
#   '4',
#   '389552',
#   '860',
#   '10544223',
#   '5910495',
#   '1783983 ',
#   'Asia',
#   '3',
#   '1163',
#   '0',
#   '121',
#   '0.6',
#   '913'],
#  ['Sri Lanka',
#   '671522',
#   25.0,
#   '16793                                ',
#   2.0,
#   '654622',
#   6.0,
#   '107',
#   -1,
#   '31124',
#   '778',
#   '6486117',
#   '300619',
#   '21575842 ',
#   'Asia',
#   '32',
#   '1285',
#   '3',
#   '1',
#   '0.09',
#   '5'],
#  ['Kuwait',
#   '662359',
#   -1,
#   '2569                                ',
#   -1,
#   '659512',
#   -1,
#   '278',
#   '2',
#   '151212',
#   '586',
#   '8416379',
#   '1921405',
#   '4380326 ',
#   'Asia',
#   '7',
#   '1705',
#   '1',
#   -1,
#   -1,
#   '63'],
#  ['Dominican Republic',
#   '647205',
#   -1,
#   '4384                                ',
#   -1,
#   '642571',
#   -1,
#   '250',
#   '4',
#   '58537',
#   '397',
#   '3657057',
#   '330765',
#   '11056370 ',
#   'North America',
#   '17',
#   '2522',
#   '3',
#   -1,
#   -1,
#   '23'],
#  ['Myanmar',
#   '633005',
#   18.0,
#   '19487                                ',
#   -1,
#   '607384',
#   76.0,
#   '6134',
#   -1,
#   '11462',
#   '353',
#   '9588427',
#   '173618',
#   '55227143 ',
#   'Asia',
#   '87',
#   '2834',
#   '6',
#   '0.3',
#   -1,
#   '111'],
#  ['Palestine',
#   '620816',
#   -1,
#   '5404                                ',
#   -1,
#   '614962',
#   -1,
#   '450',
#   '17',
#   '116137',
#   '1011',
#   '3078533',
#   '575907',
#   '5345541 ',
#   'Asia',
#   '9',
#   '989',
#   '2',
#   -1,
#   -1,
#   '84'],
#  ['Cyprus',
#   '610023',
#   -1,
#   '1218                                ',
#   -1,
#   '597900',
#   -1,
#   '10905',
#   '60',
#   '498635',
#   '996',
#   '9640118',
#   '7879860',
#   '1223387 ',
#   'Asia',
#   '2',
#   '1004',
#   '0',
#   -1,
#   -1,
#   '8,914'],
#  ['Estonia',
#   '608269',
#   -1,
#   '2757                                ',
#   -1,
#   '524990',
#   -1,
#   '80522',
#   '3',
#   '460144',
#   '2086',
#   '3592528',
#   '2717680',
#   '1321910 ',
#   'Europe',
#   '2',
#   '479',
#   '0',
#   -1,
#   -1,
#   '60,913'],
#  ['Moldova',
#   '594441',
#   -1,
#   '11906                                ',
#   -1,
#   '504142',
#   -1,
#   '78393',
#   '49',
#   '148123',
#   '2967',
#   '3216305',
#   '801437',
#   '4013171 ',
#   'Europe',
#   '7',
#   '337',
#   '1',
#   -1,
#   -1,
#   '19,534'],
#  ['Venezuela',
#   '546839',
#   39.0,
#   '5827                                ',
#   -1,
#   '540186',
#   14.0,
#   '826',
#   '36',
#   '18684',
#   '199',
#   '3359014',
#   '114771',
#   '29266991 ',
#   'South America',
#   '54',
#   '5023',
#   '9',
#   '1',
#   -1,
#   '28'],
#  ['Egypt',
#   '515645',
#   -1,
#   '24613                                ',
#   -1,
#   '442182',
#   -1,
#   '48850',
#   '122',
#   '4857',
#   '232',
#   '3693367',
#   '34792',
#   '106156692 ',
#   'Africa',
#   '206',
#   '4313',
#   '29',
#   -1,
#   -1,
#   '460'],
#  ['Libya',
#   '507070',
#   -1,
#   '6437                                ',
#   -1,
#   '500594',
#   -1,
#   '39',
#   -1,
#   '72019',
#   '914',
#   '2483318',
#   '352707',
#   '7040745 ',
#   'Africa',
#   '14',
#   '1094',
#   '3',
#   -1,
#   -1,
#   '6'],
#  ['Ethiopia',
#   '494314',
#   14.0,
#   '7572                                ',
#   -1,
#   '472213',
#   4.0,
#   '14529',
#   '2',
#   '4092',
#   '63',
#   '5348450',
#   '44271',
#   '120812698 ',
#   'Africa',
#   '244',
#   '15955',
#   '23',
#   '0.1',
#   -1,
#   '120'],
#  ['Qatar',
#   '475897',
#   271.0,
#   '684                                ',
#   -1,
#   '474083',
#   419.0,
#   '1130',
#   '1',
#   '159702',
#   '230',
#   '4065369',
#   '1364257',
#   '2979915 ',
#   'Asia',
#   '6',
#   '4357',
#   '1',
#   '91',
#   -1,
#   '379'],
#  ['Réunion',
#   '475195',
#   -1,
#   '902                                ',
#   -1,
#   '418572',
#   -1,
#   '55721',
#   '10',
#   '523307',
#   '993',
#   '1603660',
#   '1766027',
#   '908061 ',
#   'Africa',
#   '2',
#   '1007',
#   '1',
#   -1,
#   -1,
#   '61,363'],
#  ['Honduras',
#   '457508',
#   -1,
#   '11043                                ',
#   -1,
#   0,
#   0,
#   0,
#   '105',
#   '44760',
#   '1080',
#   '1557865',
#   '152414',
#   '10221247 ',
#   'North America',
#   '22',
#   '926',
#   '7',
#   -1,
#   -1,
#   '30,712'],
#  ['Armenia',
#   '445513',
#   -1,
#   '8709                                ',
#   -1,
#   '434599',
#   -1,
#   '2205',
#   -1,
#   '149905',
#   '2930',
#   '3231885',
#   '1087457',
#   '2971966 ',
#   'Asia',
#   '7',
#   '341',
#   '1',
#   -1,
#   -1,
#   '742'],
#  ['Bosnia and Herzegovina',
#   '400336',
#   -1,
#   '16190                                ',
#   -1,
#   '378170',
#   -1,
#   '5976',
#   -1,
#   '123206',
#   '4983',
#   '1878391',
#   '578088',
#   '3249317 ',
#   'Europe',
#   '8',
#   '201',
#   '2',
#   -1,
#   -1,
#   '1,839'],
#  ['Oman',
#   '399027',
#   -1,
#   '4260                                ',
#   -1,
#   '384669',
#   -1,
#   '10098',
#   '2',
#   '74949',
#   '800',
#   '25000000',
#   '4695724',
#   '5323993 ',
#   'Asia',
#   '13',
#   '1250',
#   '0',
#   -1,
#   -1,
#   '1,897'],
#  ['North Macedonia',
#   '344531',
#   -1,
#   '9567                                ',
#   -1,
#   '334335',
#   -1,
#   '629',
#   -1,
#   '165536',
#   '4597',
#   '2141032',
#   '1028697',
#   '2081304 ',
#   'Europe',
#   '6',
#   '218',
#   '1',
#   -1,
#   -1,
#   '302'],
#  ['Kenya',
#   '341030',
#   55.0,
#   '5684                                ',
#   -1,
#   '334436',
#   127.0,
#   '910',
#   '1',
#   '6067',
#   '101',
#   '3934606',
#   '69992',
#   '56215221 ',
#   'Africa',
#   '165',
#   '9890',
#   '14',
#   '1.0',
#   -1,
#   '16'],
#  ['Zambia',
#   '333685',
#   -1,
#   '4017                                ',
#   -1,
#   '329652',
#   -1,
#   '16',
#   -1,
#   '17138',
#   '206',
#   '3750980',
#   '192652',
#   '19470234 ',
#   'Africa',
#   '58',
#   '4847',
#   '5',
#   -1,
#   -1,
#   '0.8'],
#  ['Albania',
#   '333256',
#   10.0,
#   '3593                                ',
#   -1,
#   '328060',
#   5.0,
#   '1603',
#   -1,
#   '116264',
#   '1254',
#   '1941032',
#   '677173',
#   '2866374 ',
#   'Europe',
#   '9',
#   '798',
#   '1',
#   '3',
#   -1,
#   '559'],
#  ['Botswana',
#   '326344',
#   -1,
#   '2790                                ',
#   -1,
#   '322955',
#   -1,
#   '599',
#   '1',
#   '133684',
#   '1143',
#   '2026898',
#   '830300',
#   '2441162 ',
#   'Africa',
#   '7',
#   '875',
#   '1',
#   -1,
#   -1,
#   '245'],
#  ['Luxembourg',
#   '297757',
#   -1,
#   '1133                                ',
#   -1,
#   '288991',
#   -1,
#   '7633',
#   -1,
#   '463528',
#   '1764',
#   '4412567',
#   '6869188',
#   '642371 ',
#   'Europe',
#   '2',
#   '567',
#   '0',
#   -1,
#   -1,
#   '11,883'],
#  ['Montenegro',
#   '283500',
#   12.0,
#   '2789                                ',
#   -1,
#   '280478',
#   22.0,
#   '233',
#   '6',
#   '451469',
#   '4441',
#   '2659980',
#   '4235974',
#   '627950 ',
#   'Europe',
#   '2',
#   '225',
#   '0',
#   '19',
#   -1,
#   '371'],
#  ['Algeria',
#   '271023',
#   12.0,
#   '6881                                ',
#   -1,
#   '182526',
#   7.0,
#   '81616',
#   -1,
#   '5976',
#   '152',
#   '230861',
#   '5091',
#   '45350148 ',
#   'Africa',
#   '167',
#   '6591',
#   '196',
#   '0.3',
#   -1,
#   '1,800'],
#  ['Nigeria',
#   '266283',
#   -1,
#   '3155                                ',
#   -1,
#   '259640',
#   -1,
#   '3488',
#   '11',
#   '1229',
#   '15',
#   '5441162',
#   '25104',
#   '216746934 ',
#   'Africa',
#   '814',
#   '68700',
#   '40',
#   -1,
#   -1,
#   '16'],
#  ['Zimbabwe',
#   '257893',
#   -1,
#   '5606                                ',
#   -1,
#   '251904',
#   -1,
#   '383',
#   '12',
#   '16821',
#   '366',
#   '2525756',
#   '164744',
#   '15331428 ',
#   'Africa',
#   '59',
#   '2735',
#   '6',
#   -1,
#   -1,
#   '25'],
#  ['Uzbekistan',
#   '245246',
#   -1,
#   '1637                                ',
#   -1,
#   '241486',
#   -1,
#   '2123',
#   '23',
#   '7133',
#   '48',
#   '1377915',
#   '40077',
#   '34382084 ',
#   'Asia',
#   '140',
#   '21003',
#   '25',
#   -1,
#   -1,
#   '62'],
#  ['Brunei ',
#   '241044',
#   -1,
#   '225                                ',
#   -1,
#   '222140',
#   -1,
#   '18679',
#   -1,
#   '541148',
#   '505',
#   '717784',
#   '1611437',
#   '445431 ',
#   'Asia',
#   '2',
#   '1980',
#   '1',
#   -1,
#   -1,
#   '41,935'],
#  ['Mozambique',
#   '230543',
#   -1,
#   '2224                                ',
#   -1,
#   '228216',
#   -1,
#   '103',
#   '11',
#   '6967',
#   '67',
#   '1371127',
#   '41437',
#   '33089461 ',
#   'Africa',
#   '144',
#   '14878',
#   '24',
#   -1,
#   -1,
#   '3'],
#  ['Martinique',
#   '223877',
#   -1,
#   '1057                                ',
#   -1,
#   0,
#   0,
#   0,
#   '8',
#   '598462',
#   '2826',
#   '828928',
#   '2215870',
#   '374087 ',
#   'North America',
#   '2',
#   '354',
#   '0',
#   -1,
#   -1,
#   '595,359'],
#  ['Laos',
#   '216466',
#   6.0,
#   '758                                ',
#   -1,
#   0,
#   0,
#   0,
#   -1,
#   '28935',
#   '101',
#   '1233207',
#   '164845',
#   '7481023 ',
#   'Asia',
#   '35',
#   '9869',
#   '6',
#   '0.8',
#   -1,
#   '27,810'],
#  ['Iceland',
#   '207003',
#   -1,
#   '219                                ',
#   -1,
#   0,
#   0,
#   0,
#   '2',
#   '599326',
#   '634',
#   '1996384',
#   '5780036',
#   '345393 ',
#   'Europe',
#   '2',
#   '1577',
#   '0',
#   -1,
#   -1,
#   '379,565'],
#  ['Kyrgyzstan',
#   '206483',
#   -1,
#   '2991                                ',
#   -1,
#   '196406',
#   -1,
#   '7086',
#   '131',
#   '30689',
#   '445',
#   '1907195',
#   '283460',
#   '6728271 ',
#   'Asia',
#   '33',
#   '2250',
#   '4',
#   -1,
#   -1,
#   '1,053'],
#  ['Afghanistan',
#   '205189',
#   122.0,
#   '7832                                ',
#   1.0,
#   '182217',
#   84.0,
#   '15140',
#   '1124',
#   '5035',
#   '192',
#   '1150047',
#   '28219',
#   '40754388 ',
#   'Asia',
#   '199',
#   '5204',
#   '35',
#   '3',
#   '0.02',
#   '371'],
#  ['El Salvador',
#   '201785',
#   -1,
#   '4230                                ',
#   -1,
#   '179410',
#   -1,
#   '18145',
#   '8',
#   '30805',
#   '646',
#   '2610114',
#   '398467',
#   '6550389 ',
#   'North America',
#   '32',
#   '1549',
#   '3',
#   -1,
#   -1,
#   '2,770'],
#  ['Guadeloupe',
#   '197105',
#   -1,
#   '993                                ',
#   -1,
#   0,
#   0,
#   0,
#   '19',
#   '493016',
#   '2484',
#   '938039',
#   '2346306',
#   '399794 ',
#   'North America',
#   '2',
#   '403',
#   '0',
#   -1,
#   -1,
#   '484,905'],
#  ['Maldives',
#   '185549',
#   -1,
#   '311                                ',
#   -1,
#   '163687',
#   -1,
#   '21551',
#   '25',
#   '342984',
#   '575',
#   '2213831',
#   '4092223',
#   '540985 ',
#   'Asia',
#   '3',
#   '1740',
#   '0',
#   -1,
#   -1,
#   '39,837'],
#  ['Trinidad and Tobago',
#   '185094',
#   -1,
#   '4263                                ',
#   -1,
#   '180644',
#   -1,
#   '187',
#   '8',
#   '131591',
#   '3031',
#   '862808',
#   '613406',
#   '1406585 ',
#   'North America',
#   '8',
#   '330',
#   '2',
#   -1,
#   -1,
#   '133'],
#  ['Ghana',
#   '170996',
#   24.0,
#   '1461                                ',
#   -1,
#   '169511',
#   71.0,
#   '24',
#   '2',
#   '5278',
#   '45',
#   '2520078',
#   '77791',
#   '32395450 ',
#   'Africa',
#   '189',
#   '22173',
#   '13',
#   '0.7',
#   -1,
#   '0.7'],
#  ['Namibia',
#   '169946',
#   -1,
#   '4080                                ',
#   -1,
#   '165826',
#   -1,
#   '40',
#   -1,
#   '64523',
#   '1549',
#   '1062663',
#   '403460',
#   '2633874 ',
#   'Africa',
#   '15',
#   '646',
#   '2',
#   -1,
#   -1,
#   '15'],
#  ['Uganda',
#   '169663',
#   -1,
#   '3630                                ',
#   -1,
#   '100431',
#   -1,
#   '65602',
#   '3',
#   '3503',
#   '75',
#   '3012408',
#   '62198',
#   '48432863 ',
#   'Africa',
#   '285',
#   '13342',
#   '16',
#   -1,
#   -1,
#   '1,354'],
#  ['Jamaica',
#   '151931',
#   -1,
#   '3320                                ',
#   -1,
#   '99392',
#   -1,
#   '49219',
#   -1,
#   '50897',
#   '1112',
#   '1183986',
#   '396633',
#   '2985094 ',
#   'North America',
#   '20',
#   '899',
#   '3',
#   -1,
#   -1,
#   '16,488'],
#  ['Cambodia',
#   '138028',
#   4.0,
#   '3056                                ',
#   -1,
#   '134940',
#   -1,
#   '32',
#   -1,
#   '8040',
#   '178',
#   '3091420',
#   '180062',
#   '17168639 ',
#   'Asia',
#   '124',
#   '5618',
#   '6',
#   '0.2',
#   -1,
#   '2'],
#  ['Rwanda',
#   '132643',
#   -1,
#   '1467                                ',
#   -1,
#   '131112',
#   -1,
#   '64',
#   -1,
#   '9753',
#   '108',
#   '5882479',
#   '432520',
#   '13600464 ',
#   'Africa',
#   '103',
#   '9271',
#   '2',
#   -1,
#   -1,
#   '5'],
#  ['Cameroon',
#   '123993',
#   -1,
#   '1965                                ',
#   -1,
#   '118616',
#   -1,
#   '3412',
#   '13',
#   '4442',
#   '70',
#   '1751774',
#   '62762',
#   '27911548 ',
#   'Africa',
#   '225',
#   '14204',
#   '16',
#   -1,
#   -1,
#   '122'],
#  ['Malta',
#   '115695',
#   14.0,
#   '808                                ',
#   -1,
#   '114256',
#   14.0,
#   '631',
#   '4',
#   '260555',
#   '1820',
#   '2086811',
#   '4699675',
#   '444033 ',
#   'Europe',
#   '4',
#   '550',
#   '0',
#   '32',
#   -1,
#   '1,421'],
#  ['Barbados',
#   '103545',
#   -1,
#   '564                                ',
#   -1,
#   '102435',
#   -1,
#   '546',
#   -1,
#   '359503',
#   '1958',
#   '773895',
#   '2686921',
#   '288023 ',
#   'North America',
#   '3',
#   '511',
#   '0',
#   -1,
#   -1,
#   '1,896'],
#  ['Angola',
#   '103131',
#   -1,
#   '1917                                ',
#   -1,
#   '101155',
#   -1,
#   '59',
#   -1,
#   '2944',
#   '55',
#   '1499795',
#   '42818',
#   '35027343 ',
#   'Africa',
#   '340',
#   '18272',
#   '23',
#   -1,
#   -1,
#   '2'],
#  ['Channel Islands',
#   '95255',
#   -1,
#   '207                                ',
#   -1,
#   '94593',
#   -1,
#   '455',
#   -1,
#   '539802',
#   '1173',
#   '1252808',
#   '7099551',
#   '176463 ',
#   'Europe',
#   '2',
#   '852',
#   '0',
#   -1,
#   -1,
#   '2,578'],
#  ['French Guiana',
#   '94729',
#   -1,
#   '411                                ',
#   -1,
#   '11254',
#   -1,
#   '83064',
#   '2',
#   '301522',
#   '1308',
#   '651257',
#   '2072951',
#   '314169 ',
#   'South America',
#   '3',
#   '764',
#   '0',
#   -1,
#   -1,
#   '264,393'],
#  ['DRC',
#   '93837',
#   -1,
#   '1452                                ',
#   -1,
#   '83590',
#   -1,
#   '8795',
#   -1,
#   '985',
#   '15',
#   '846704',
#   '8890',
#   '95240792 ',
#   'Africa',
#   '1015',
#   '65593',
#   '112',
#   -1,
#   -1,
#   '92'],
#  ['Senegal',
#   '88842',
#   -1,
#   '1968                                ',
#   -1,
#   '86833',
#   -1,
#   '41',
#   -1,
#   '5032',
#   '111',
#   '1146543',
#   '64946',
#   '17653671 ',
#   'Africa',
#   '199',
#   '8970',
#   '15',
#   -1,
#   -1,
#   '2'],
#  ['Malawi',
#   '88073',
#   -1,
#   '2685                                ',
#   -1,
#   '84993',
#   -1,
#   '395',
#   '67',
#   '4364',
#   '133',
#   '622351',
#   '30839',
#   '20180839 ',
#   'Africa',
#   '229',
#   '7516',
#   '32',
#   -1,
#   -1,
#   '20'],
#  ['Ivory Coast',
#   '87870',
#   -1,
#   '830                                ',
#   -1,
#   '87025',
#   -1,
#   '15',
#   -1,
#   '3167',
#   '30',
#   '1649487',
#   '59457',
#   '27742298 ',
#   'Africa',
#   '316',
#   '33424',
#   '17',
#   -1,
#   -1,
#   '0.5'],
#  ['Suriname',
#   '81228',
#   -1,
#   '1392                                ',
#   -1,
#   0,
#   0,
#   0,
#   -1,
#   '136099',
#   '2332',
#   '239603',
#   '401459',
#   '596831 ',
#   'South America',
#   '7',
#   '429',
#   '2',
#   -1,
#   -1,
#   '50,580'],
#  ['French Polynesia',
#   '76827',
#   -1,
#   '649                                ',
#   -1,
#   0,
#   0,
#   0,
#   '7',
#   '270361',
#   '2284',
#   -1,
#   -1,
#   '284164 ',
#   'Australia/Oceania',
#   '4',
#   '438',
#   -1,
#   -1,
#   -1,
#   '150,188'],
#  ['New Caledonia',
#   '74682',
#   -1,
#   '314                                ',
#   -1,
#   '74085',
#   -1,
#   '283',
#   '9',
#   '256714',
#   '1079',
#   '98964',
#   '340182',
#   '290915 ',
#   'Australia/Oceania',
#   '4',
#   '926',
#   '3',
#   -1,
#   -1,
#   '973'],
#  ['Eswatini',
#   '73770',
#   62.0,
#   '1422                                ',
#   -1,
#   '72255',
#   94.0,
#   '93',
#   -1,
#   '62263',
#   '1200',
#   '1047886',
#   '884429',
#   '1184817 ',
#   'Africa',
#   '16',
#   '833',
#   '1',
#   '52',
#   -1,
#   '78'],
#  ['Guyana',
#   '71541',
#   5.0,
#   '1281                                ',
#   -1,
#   '70175',
#   -1,
#   '85',
#   -1,
#   '90097',
#   '1613',
#   '704440',
#   '887154',
#   '794045 ',
#   'South America',
#   '11',
#   '620',
#   '1',
#   '6',
#   -1,
#   '107'],
#  ['Belize',
#   '68988',
#   -1,
#   '687                                ',
#   -1,
#   '68291',
#   -1,
#   '10',
#   '6',
#   '167369',
#   '1667',
#   '576016',
#   '1397453',
#   '412190 ',
#   'North America',
#   '6',
#   '600',
#   '1',
#   -1,
#   -1,
#   '24'],
#  ['Fiji',
#   '68307',
#   -1,
#   '878                                ',
#   -1,
#   '66351',
#   -1,
#   '1078',
#   -1,
#   '75107',
#   '965',
#   '664856',
#   '731040',
#   '909466 ',
#   'Australia/Oceania',
#   '13',
#   '1036',
#   '1',
#   -1,
#   -1,
#   '1,185'],
#  ['Madagascar',
#   '67054',
#   195.0,
#   '1411                                ',
#   -1,
#   '65379',
#   39.0,
#   '264',
#   -1,
#   '2298',
#   '48',
#   '517050',
#   '17720',
#   '29178077 ',
#   'Africa',
#   '435',
#   '20679',
#   '56',
#   '7',
#   -1,
#   '9'],
#  ['Sudan',
#   '63595',
#   -1,
#   '4981                                ',
#   -1,
#   '57814',
#   -1,
#   '800',
#   -1,
#   '1383',
#   '108',
#   '562941',
#   '12240',
#   '45992020 ',
#   'Africa',
#   '723',
#   '9233',
#   '82',
#   -1,
#   -1,
#   '17'],
#  ['Mauritania',
#   '63419',
#   1.0,
#   '997                                ',
#   -1,
#   '62408',
#   1.0,
#   '14',
#   -1,
#   '12937',
#   '203',
#   '1006075',
#   '205238',
#   '4901981 ',
#   'Africa',
#   '77',
#   '4917',
#   '5',
#   '0.2',
#   -1,
#   '3'],
#  ['Cabo Verde',
#   '62802',
#   -1,
#   '410                                ',
#   -1,
#   '62207',
#   -1,
#   '185',
#   '23',
#   '110630',
#   '722',
#   '401622',
#   '707482',
#   '567678 ',
#   'Africa',
#   '9',
#   '1385',
#   '1',
#   -1,
#   -1,
#   '326'],
#  ['Bhutan',
#   '62460',
#   -1,
#   '21                                ',
#   -1,
#   '61564',
#   -1,
#   '875',
#   -1,
#   '79270',
#   '27',
#   '2303734',
#   '2923739',
#   '787941 ',
#   'Asia',
#   '13',
#   '37521',
#   '0',
#   -1,
#   -1,
#   '1,110'],
#  ['Syria',
#   '57386',
#   -1,
#   '3163                                ',
#   -1,
#   '54216',
#   -1,
#   '7',
#   -1,
#   '2963',
#   '163',
#   '146269',
#   '7553',
#   '19364809 ',
#   'Asia',
#   '337',
#   '6122',
#   '132',
#   -1,
#   -1,
#   '0.4'],
#  ['Burundi',
#   '50639',
#   -1,
#   '38                                ',
#   -1,
#   '50418',
#   -1,
#   '183',
#   -1,
#   '4011',
#   '3',
#   '345742',
#   '27386',
#   '12624840 ',
#   'Africa',
#   '249',
#   '332233',
#   '37',
#   -1,
#   -1,
#   '14'],
#  ['Seychelles',
#   '49380',
#   -1,
#   '171                                ',
#   -1,
#   '48626',
#   -1,
#   '583',
#   -1,
#   '496651',
#   '1720',
#   -1,
#   -1,
#   '99426 ',
#   'Africa',
#   '2',
#   '581',
#   -1,
#   -1,
#   -1,
#   '5,864'],
#  ['Gabon',
#   '48972',
#   -1,
#   '306                                ',
#   -1,
#   '48491',
#   -1,
#   '175',
#   -1,
#   '21004',
#   '131',
#   '1620866',
#   '695193',
#   '2331533 ',
#   'Africa',
#   '48',
#   '7619',
#   '1',
#   -1,
#   -1,
#   '75'],
#  ['Andorra',
#   '46824',
#   -1,
#   '156                                ',
#   -1,
#   '46457',
#   -1,
#   '211',
#   '14',
#   '604469',
#   '2014',
#   '249838',
#   '3225256',
#   '77463 ',
#   'Europe',
#   '2',
#   '497',
#   '0',
#   -1,
#   -1,
#   '2,724'],
#  ['Papua New Guinea',
#   '45819',
#   -1,
#   '668                                ',
#   -1,
#   '43982',
#   -1,
#   '1169',
#   '7',
#   '4931',
#   '72',
#   '249149',
#   '26813',
#   '9292169 ',
#   'Australia/Oceania',
#   '203',
#   '13910',
#   '37',
#   -1,
#   -1,
#   '126'],
#  ['Curaçao',
#   '45536',
#   -1,
#   '294                                ',
#   -1,
#   '44720',
#   -1,
#   '522',
#   '3',
#   '275094',
#   '1776',
#   '496693',
#   '3000640',
#   '165529 ',
#   'North America',
#   '4',
#   '563',
#   '0',
#   -1,
#   -1,
#   '3,154'],
#  ['Aruba',
#   '43494',
#   -1,
#   '235                                ',
#   -1,
#   '42438',
#   -1,
#   '821',
#   '2',
#   '404186',
#   '2184',
#   '177885',
#   '1653068',
#   '107609 ',
#   'North America',
#   '2',
#   '458',
#   '1',
#   -1,
#   -1,
#   '7,629'],
#  ['Mauritius',
#   '40922',
#   -1,
#   '1032                                ',
#   -1,
#   '39160',
#   -1,
#   '730',
#   -1,
#   '32103',
#   '810',
#   '358675',
#   '281374',
#   '1274727 ',
#   'Africa',
#   '31',
#   '1235',
#   '4',
#   -1,
#   -1,
#   '573'],
#  ['Mayotte',
#   '40612',
#   -1,
#   '187                                ',
#   -1,
#   0,
#   0,
#   0,
#   -1,
#   '141872',
#   '653',
#   '176919',
#   '618038',
#   '286259 ',
#   'Africa',
#   '7',
#   '1531',
#   '2',
#   -1,
#   -1,
#   '130,864'],
#  ['Tanzania',
#   '40311',
#   -1,
#   '845                                ',
#   -1,
#   0,
#   0,
#   0,
#   '7',
#   '637',
#   '13',
#   -1,
#   -1,
#   '63298550 ',
#   'Africa',
#   '1570',
#   '74910',
#   -1,
#   -1,
#   -1,
#   '621'],
#  ['Togo',
#   '39323',
#   2.0,
#   '290                                ',
#   -1,
#   '39023',
#   -1,
#   '10',
#   -1,
#   '4530',
#   '33',
#   '800360',
#   '92198',
#   '8680837 ',
#   'Africa',
#   '221',
#   '29934',
#   '11',
#   '0.2',
#   -1,
#   '1'],
#  ['Guinea',
#   '38153',
#   -1,
#   '464                                ',
#   -1,
#   '37218',
#   -1,
#   '471',
#   '8',
#   '2752',
#   '33',
#   '660107',
#   '47607',
#   '13865691 ',
#   'Africa',
#   '363',
#   '29883',
#   '21',
#   -1,
#   -1,
#   '34'],
#  ['Isle of Man',
#   '38008',
#   -1,
#   '116                                ',
#   -1,
#   0,
#   0,
#   0,
#   -1,
#   '443335',
#   '1353',
#   '150753',
#   '1758422',
#   '85732 ',
#   'Europe',
#   '2',
#   '739',
#   '1',
#   -1,
#   -1,
#   '129,450'],
#  ['Bahamas',
#   '37453',
#   -1,
#   '833                                ',
#   -1,
#   '36337',
#   -1,
#   '283',
#   '1',
#   '93512',
#   '2080',
#   '257839',
#   '643767',
#   '400516 ',
#   'North America',
#   '11',
#   '481',
#   '2',
#   -1,
#   -1,
#   '707'],
#  ['Faeroe Islands',
#   '34658',
#   -1,
#   '28                                ',
#   -1,
#   0,
#   0,
#   0,
#   '5',
#   '703959',
#   '569',
#   '778000',
#   '15802409',
#   '49233 ',
#   'Europe',
#   '1',
#   '1758',
#   '0',
#   -1,
#   -1,
#   '547,133'],
#  ['Lesotho',
#   '34490',
#   -1,
#   '706                                ',
#   -1,
#   '25980',
#   -1,
#   '7804',
#   -1,
#   '15852',
#   '324',
#   '431221',
#   '198199',
#   '2175699 ',
#   'Africa',
#   '63',
#   '3082',
#   '5',
#   -1,
#   -1,
#   '3,587'],
#  ['Haiti',
#   '33837',
#   -1,
#   '860                                ',
#   -1,
#   '32815',
#   -1,
#   '162',
#   -1,
#   '2897',
#   '74',
#   '132422',
#   '11337',
#   '11680283 ',
#   'North America',
#   '345',
#   '13582',
#   '88',
#   -1,
#   -1,
#   '14'],
#  ['Mali',
#   '32755',
#   -1,
#   '742                                ',
#   -1,
#   '31927',
#   1.0,
#   '86',
#   -1,
#   '1525',
#   '35',
#   '775801',
#   '36128',
#   '21473764 ',
#   'Africa',
#   '656',
#   '28940',
#   '28',
#   -1,
#   -1,
#   '4'],
#  ['Cayman Islands',
#   '31194',
#   -1,
#   '36                                ',
#   -1,
#   '8553',
#   -1,
#   '22605',
#   '1',
#   '463665',
#   '535',
#   '222773',
#   '3311280',
#   '67277 ',
#   'North America',
#   '2',
#   '1869',
#   '0',
#   -1,
#   -1,
#   '335,999'],
#  ['Saint Lucia',
#   '29550',
#   -1,
#   '404                                ',
#   -1,
#   '29095',
#   -1,
#   '51',
#   -1,
#   '159632',
#   '2182',
#   '210983',
#   '1139752',
#   '185113 ',
#   'North America',
#   '6',
#   '458',
#   '1',
#   -1,
#   -1,
#   '276'],
#  ['Benin',
#   '27922',
#   -1,
#   '163                                ',
#   -1,
#   '27746',
#   -1,
#   '13',
#   '5',
#   '2184',
#   '13',
#   '604310',
#   '47268',
#   '12784726 ',
#   'Africa',
#   '458',
#   '78434',
#   '21',
#   -1,
#   -1,
#   '1'],
#  ['Somalia',
#   '27254',
#   -1,
#   '1361                                ',
#   -1,
#   '13182',
#   -1,
#   '12711',
#   -1,
#   '1618',
#   '81',
#   '400466',
#   '23778',
#   '16841795 ',
#   'Africa',
#   '618',
#   '12375',
#   '42',
#   -1,
#   -1,
#   '755'],
#  ['Congo',
#   '25375',
#   -1,
#   '386                                ',
#   -1,
#   '24006',
#   -1,
#   '983',
#   -1,
#   '4377',
#   '67',
#   '347815',
#   '59991',
#   '5797805 ',
#   'Africa',
#   '228',
#   '15020',
#   '17',
#   -1,
#   -1,
#   '170'],
#  ['Timor-Leste',
#   '23323',
#   -1,
#   '138                                ',
#   -1,
#   '23102',
#   -1,
#   '83',
#   -1,
#   '17031',
#   '101',
#   '278529',
#   '203391',
#   '1369429 ',
#   'Asia',
#   '59',
#   '9923',
#   '5',
#   -1,
#   -1,
#   '61'],
#  ['Micronesia',
#   '22203',
#   -1,
#   '55                                ',
#   -1,
#   0,
#   0,
#   0,
#   '1',
#   '188979',
#   '468',
#   '21923',
#   '186596',
#   '117489 ',
#   'Australia/Oceania',
#   '5',
#   '2136',
#   '5',
#   -1,
#   -1,
#   '187,030'],
#  ['San Marino',
#   '21798',
#   -1,
#   '119                                ',
#   -1,
#   '21554',
#   -1,
#   '125',
#   '4',
#   '639519',
#   '3491',
#   '157634',
#   '4624732',
#   '34085 ',
#   'Europe',
#   '2',
#   '286',
#   '0',
#   -1,
#   -1,
#   '3,667'],
#  ['Burkina Faso',
#   '21631',
#   -1,
#   '387                                ',
#   -1,
#   '21143',
#   -1,
#   '101',
#   -1,
#   '979',
#   '18',
#   '248995',
#   '11265',
#   '22102838 ',
#   'Africa',
#   '1022',
#   '57113',
#   '89',
#   -1,
#   -1,
#   '5'],
#  ['Solomon Islands',
#   '21544',
#   -1,
#   '153                                ',
#   -1,
#   '16357',
#   -1,
#   '5034',
#   '1',
#   '29874',
#   '212',
#   '5117',
#   '7096',
#   '721159 ',
#   'Australia/Oceania',
#   '33',
#   '4713',
#   '141',
#   -1,
#   -1,
#   '6,980'],
#  ['Liechtenstein',
#   '20829',
#   9.0,
#   '87                                ',
#   -1,
#   '20697',
#   10.0,
#   '45',
#   -1,
#   '542606',
#   '2266',
#   '102174',
#   '2661682',
#   '38387 ',
#   'Europe',
#   '2',
#   '441',
#   '0',
#   '234',
#   -1,
#   '1,172'],
#  ['Gibraltar',
#   '20184',
#   -1,
#   '110                                ',
#   -1,
#   '16579',
#   -1,
#   '3495',
#   -1,
#   '598861',
#   '3264',
#   '534283',
#   '15852213',
#   '33704 ',
#   'Europe',
#   '2',
#   '306',
#   '0',
#   -1,
#   -1,
#   '103,697'],
#  ['Grenada',
#   '19613',
#   -1,
#   '237                                ',
#   -1,
#   '19358',
#   -1,
#   '18',
#   '4',
#   '172840',
#   '2089',
#   '182981',
#   '1612523',
#   '113475 ',
#   'North America',
#   '6',
#   '479',
#   '1',
#   -1,
#   -1,
#   '159'],
#  ['Nicaragua',
#   '18491',
#   -1,
#   '225                                ',
#   -1,
#   '4225',
#   -1,
#   '14041',
#   -1,
#   '2728',
#   '33',
#   -1,
#   -1,
#   '6779100 ',
#   'North America',
#   '367',
#   '30129',
#   -1,
#   -1,
#   -1,
#   '2,071'],
#  ['Bermuda',
#   '18463',
#   -1,
#   '151                                ',
#   -1,
#   '18289',
#   -1,
#   '23',
#   -1,
#   '298084',
#   '2438',
#   '1018578',
#   '16444857',
#   '61939 ',
#   'North America',
#   '3',
#   '410',
#   '0',
#   -1,
#   -1,
#   '371'],
#  ['South Sudan',
#   '18339',
#   -1,
#   '138                                ',
#   -1,
#   '18115',
#   -1,
#   '86',
#   '1',
#   '1578',
#   '12',
#   '410280',
#   '35313',
#   '11618511 ',
#   'Africa',
#   '634',
#   '84192',
#   '28',
#   -1,
#   -1,
#   '7'],
#  ['Tajikistan',
#   '17786',
#   -1,
#   '125                                ',
#   -1,
#   '17264',
#   -1,
#   '397',
#   -1,
#   '1786',
#   '13',
#   -1,
#   -1,
#   '9957464 ',
#   'Asia',
#   '560',
#   '79660',
#   -1,
#   -1,
#   -1,
#   '40'],
#  ['Equatorial Guinea',
#   '17182',
#   -1,
#   '183                                ',
#   -1,
#   '16873',
#   -1,
#   '126',
#   '5',
#   '11480',
#   '122',
#   '365697',
#   '244342',
#   '1496662 ',
#   'Africa',
#   '87',
#   '8178',
#   '4',
#   -1,
#   -1,
#   '84'],
#  ['Tonga',
#   '16182',
#   -1,
#   '12                                ',
#   -1,
#   '15638',
#   -1,
#   '532',
#   -1,
#   '150182',
#   '111',
#   '535009',
#   '4965327',
#   '107749 ',
#   'Australia/Oceania',
#   '7',
#   '8979',
#   '0',
#   -1,
#   -1,
#   '4,937'],
#  ['Samoa',
#   '15946',
#   -1,
#   '29                                ',
#   -1,
#   '1605',
#   -1,
#   '14312',
#   '4',
#   '78847',
#   '143',
#   '187397',
#   '926612',
#   '202239 ',
#   'Australia/Oceania',
#   '13',
#   '6974',
#   '1',
#   -1,
#   -1,
#   '70,768'],
#  ['Dominica',
#   '15760',
#   -1,
#   '74                                ',
#   -1,
#   '15673',
#   -1,
#   '13',
#   -1,
#   '217848',
#   '1023',
#   '229344',
#   '3170187',
#   '72344 ',
#   'North America',
#   '5',
#   '978',
#   '0',
#   -1,
#   -1,
#   '180'],
#  ['Djibouti',
#   '15690',
#   -1,
#   '189                                ',
#   -1,
#   '15427',
#   -1,
#   '74',
#   -1,
#   '15441',
#   '186',
#   '305941',
#   '301094',
#   '1016097 ',
#   'Africa',
#   '65',
#   '5376',
#   '3',
#   -1,
#   -1,
#   '73'],
#  ['Marshall Islands',
#   '15501',
#   -1,
#   '17                                ',
#   -1,
#   '15372',
#   -1,
#   '112',
#   '22',
#   '258105',
#   '283',
#   -1,
#   -1,
#   '60057 ',
#   'Australia/Oceania',
#   '4',
#   '3533',
#   -1,
#   -1,
#   -1,
#   '1,865'],
#  ['CAR',
#   '15289',
#   -1,
#   '113                                ',
#   -1,
#   '14615',
#   -1,
#   '561',
#   '2',
#   '3048',
#   '23',
#   '81294',
#   '16205',
#   '5016678 ',
#   'Africa',
#   '328',
#   '44395',
#   '62',
#   -1,
#   -1,
#   '112'],
#  ['Monaco',
#   '15195',
#   -1,
#   '63                                ',
#   -1,
#   '15059',
#   -1,
#   '73',
#   '4',
#   '381947',
#   '1584',
#   '78646',
#   '1976875',
#   '39783 ',
#   'Europe',
#   '3',
#   '631',
#   '1',
#   -1,
#   -1,
#   '1,835'],
#  ['Gambia',
#   '12580',
#   -1,
#   '372                                ',
#   -1,
#   '12174',
#   -1,
#   '34',
#   -1,
#   '4917',
#   '145',
#   '155686',
#   '60851',
#   '2558482 ',
#   'Africa',
#   '203',
#   '6878',
#   '16',
#   -1,
#   -1,
#   '13'],
#  ['Saint Martin',
#   '12034',
#   -1,
#   '63                                ',
#   -1,
#   '1399',
#   -1,
#   '10572',
#   '7',
#   '302895',
#   '1586',
#   '112382',
#   '2828643',
#   '39730 ',
#   'North America',
#   '3',
#   '631',
#   '0',
#   -1,
#   -1,
#   '266,096'],
#  ['Greenland',
#   '11971',
#   -1,
#   '21                                ',
#   -1,
#   '2761',
#   -1,
#   '9189',
#   '4',
#   '210117',
#   '369',
#   '164926',
#   '2894810',
#   '56973 ',
#   'North America',
#   '5',
#   '2713',
#   '0',
#   -1,
#   -1,
#   '161,287'],
#  ['Vanuatu',
#   '11952',
#   -1,
#   '14                                ',
#   -1,
#   '11937',
#   -1,
#   '1',
#   -1,
#   '37137',
#   '44',
#   '24976',
#   '77606',
#   '321832 ',
#   'Australia/Oceania',
#   '27',
#   '22988',
#   '13',
#   -1,
#   -1,
#   '3'],
#  ['Yemen',
#   '11945',
#   -1,
#   '2159                                ',
#   -1,
#   '9124',
#   -1,
#   '662',
#   '23',
#   '383',
#   '69',
#   '329592',
#   '10579',
#   '31154867 ',
#   'Asia',
#   '2608',
#   '14430',
#   '95',
#   -1,
#   -1,
#   '21'],
#  ['Caribbean Netherlands',
#   '11402',
#   -1,
#   '36                                ',
#   -1,
#   '10476',
#   -1,
#   '890',
#   -1,
#   '427891',
#   '1351',
#   '30126',
#   '1130559',
#   '26647 ',
#   'North America',
#   '2',
#   '740',
#   '1',
#   -1,
#   -1,
#   '33,400'],
#  ['Sint Maarten',
#   '10931',
#   -1,
#   '89                                ',
#   -1,
#   '10833',
#   -1,
#   '9',
#   -1,
#   '248624',
#   '2024',
#   '62056',
#   '1411454',
#   '43966 ',
#   'North America',
#   '4',
#   '494',
#   '1',
#   -1,
#   -1,
#   '205'],
#  ['Niger',
#   '9931',
#   -1,
#   '312                                ',
#   -1,
#   '8890',
#   -1,
#   '729',
#   '1',
#   '381',
#   '12',
#   '254538',
#   '9759',
#   '26083660 ',
#   'Africa',
#   '2626',
#   '83601',
#   '102',
#   -1,
#   -1,
#   '28'],
#  ['Antigua and Barbuda',
#   '9106',
#   -1,
#   '146                                ',
#   -1,
#   '8954',
#   -1,
#   '6',
#   '1',
#   '91509',
#   '1467',
#   '18901',
#   '189943',
#   '99509 ',
#   'North America',
#   '11',
#   '682',
#   '5',
#   -1,
#   -1,
#   '60'],
#  ['Comoros',
#   '8941',
#   -1,
#   '161                                ',
#   -1,
#   '8751',
#   -1,
#   '29',
#   -1,
#   '9853',
#   '177',
#   -1,
#   -1,
#   '907419 ',
#   'Africa',
#   '101',
#   '5636',
#   -1,
#   -1,
#   -1,
#   '32'],
#  ['Guinea-Bissau',
#   '8848',
#   -1,
#   '176                                ',
#   -1,
#   '8642',
#   -1,
#   '30',
#   '6',
#   '4288',
#   '85',
#   '145231',
#   '70385',
#   '2063367 ',
#   'Africa',
#   '233',
#   '11724',
#   '14',
#   -1,
#   -1,
#   '15'],
#  ['Liberia',
#   '8014',
#   -1,
#   '294                                ',
#   -1,
#   '7705',
#   -1,
#   '15',
#   '2',
#   '1511',
#   '55',
#   '139824',
#   '26356',
#   '5305117 ',
#   'Africa',
#   '662',
#   '18045',
#   '38',
#   -1,
#   -1,
#   '3'],
#  ['Sierra Leone',
#   '7758',
#   -1,
#   '126                                ',
#   -1,
#   0,
#   0,
#   0,
#   -1,
#   '934',
#   '15',
#   '259958',
#   '31296',
#   '8306436 ',
#   'Africa',
#   '1071',
#   '65924',
#   '32',
#   -1,
#   -1,
#   '330'],
#  ['Chad',
#   '7637',
#   -1,
#   '194                                ',
#   -1,
#   '4874',
#   -1,
#   '2569',
#   -1,
#   '439',
#   '11',
#   '191341',
#   '10988',
#   '17413580 ',
#   'Africa',
#   '2280',
#   '89761',
#   '91',
#   -1,
#   -1,
#   '148'],
#  ['British Virgin Islands',
#   '7305',
#   -1,
#   '64                                ',
#   -1,
#   0,
#   0,
#   0,
#   -1,
#   '238757',
#   '2092',
#   '107339',
#   '3508269',
#   '30596 ',
#   'North America',
#   '4',
#   '478',
#   '0',
#   -1,
#   -1,
#   '392'],
#  ['St. Vincent Grenadines',
#   '7112',
#   -1,
#   '115                                ',
#   -1,
#   '6641',
#   -1,
#   '356',
#   -1,
#   '63756',
#   '1031',
#   '100856',
#   '904125',
#   '111551 ',
#   'North America',
#   '16',
#   '970',
#   '1',
#   -1,
#   -1,
#   '3,191'],
#  ['Saint Kitts and Nevis',
#   '6552',
#   -1,
#   '46                                ',
#   -1,
#   '6482',
#   -1,
#   '24',
#   -1,
#   '121624',
#   '854',
#   '124861',
#   '2317778',
#   '53871 ',
#   'North America',
#   '8',
#   '1171',
#   '0',
#   -1,
#   -1,
#   '446'],
#  ['Turks and Caicos',
#   '6431',
#   -1,
#   '36                                ',
#   -1,
#   '6364',
#   -1,
#   '31',
#   '4',
#   '161823',
#   '906',
#   '550203',
#   '13844720',
#   '39741 ',
#   'North America',
#   '6',
#   '1104',
#   '0',
#   -1,
#   -1,
#   '780'],
#  ['Cook Islands',
#   '6389',
#   -1,
#   '1                                ',
#   -1,
#   '6384',
#   -1,
#   '4',
#   -1,
#   '363610',
#   '57',
#   '19690',
#   '1120596',
#   '17571 ',
#   'Australia/Oceania',
#   '3',
#   '17571',
#   '1',
#   -1,
#   -1,
#   '228'],
#  ['Palau',
#   '5684',
#   -1,
#   '7                                ',
#   -1,
#   '5576',
#   -1,
#   '101',
#   '1',
#   '311742',
#   '384',
#   '66613',
#   '3653431',
#   '18233 ',
#   'Australia/Oceania',
#   '3',
#   '2605',
#   '0',
#   -1,
#   -1,
#   '5,539'],
#  ['St. Barth',
#   '5336',
#   -1,
#   '6                                ',
#   -1,
#   0,
#   0,
#   0,
#   -1,
#   '536551',
#   '603',
#   '78646',
#   '7908095',
#   '9945 ',
#   'North America',
#   '2',
#   '1658',
#   '0',
#   -1,
#   -1,
#   '489,492'],
#  ['Nauru',
#   '4618',
#   -1,
#   '1                                ',
#   -1,
#   '4609',
#   -1,
#   '8',
#   -1,
#   '423553',
#   '92',
#   '20509',
#   '1881042',
#   '10903 ',
#   'Australia/Oceania',
#   '2',
#   '10903',
#   '1',
#   -1,
#   -1,
#   '734'],
#  ['Anguilla',
#   '3904',
#   -1,
#   '12                                ',
#   -1,
#   '3879',
#   -1,
#   '13',
#   '4',
#   '256336',
#   '788',
#   '51382',
#   '3373736',
#   '15230 ',
#   'North America',
#   '4',
#   '1269',
#   '0',
#   -1,
#   -1,
#   '854'],
#  ['Kiribati',
#   '3430',
#   -1,
#   '13                                ',
#   -1,
#   '2703',
#   -1,
#   '714',
#   '3',
#   '27792',
#   '105',
#   -1,
#   -1,
#   '123419 ',
#   'Australia/Oceania',
#   '36',
#   '9494',
#   -1,
#   -1,
#   -1,
#   '5,785'],
#  ['Saint Pierre Miquelon',
#   '3231',
#   -1,
#   '1                                ',
#   -1,
#   '2449',
#   -1,
#   '781',
#   '1',
#   '561035',
#   '174',
#   '25120',
#   '4361868',
#   '5759 ',
#   'North America',
#   '2',
#   '5759',
#   '0',
#   -1,
#   -1,
#   '135,614'],
#  ['Tuvalu',
#   '2364',
#   346.0,
#   -1,
#   -1,
#   -1,
#   -1,
#   '2364',
#   -1,
#   '195922',
#   -1,
#   -1,
#   -1,
#   '12066 ',
#   'Australia/Oceania',
#   '5',
#   -1,
#   -1,
#   '28676',
#   -1,
#   '195,922'],
#  ['Saint Helena',
#   '1806',
#   -1,
#   -1,
#   -1,
#   '2',
#   -1,
#   '1804',
#   -1,
#   '295339',
#   -1,
#   -1,
#   -1,
#   '6115 ',
#   'Africa',
#   '3',
#   -1,
#   -1,
#   -1,
#   -1,
#   '295,012'],
#  ['Montserrat',
#   '1403',
#   -1,
#   '8                                ',
#   -1,
#   '1376',
#   -1,
#   '19',
#   -1,
#   '282578',
#   '1611',
#   '17762',
#   '3577442',
#   '4965 ',
#   'North America',
#   '4',
#   '621',
#   '0',
#   -1,
#   -1,
#   '3,827'],
#  ['Macao',
#   '796',
#   -1,
#   '6                                ',
#   -1,
#   '789',
#   -1,
#   '1',
#   -1,
#   '1193',
#   '9',
#   '7850',
#   '11760',
#   '667490 ',
#   'Asia',
#   '839',
#   '111248',
#   '85',
#   -1,
#   -1,
#   '1'],
#  ['Wallis and Futuna',
#   '761',
#   -1,
#   '7                                ',
#   -1,
#   '438',
#   -1,
#   '316',
#   -1,
#   '69295',
#   '637',
#   '20508',
#   '1867419',
#   '10982 ',
#   'Australia/Oceania',
#   '14',
#   '1569',
#   '1',
#   -1,
#   -1,
#   '28,774'],
#  ['Niue',
#   '100',
#   2.0,
#   -1,
#   -1,
#   '86',
#   1.0,
#   '14',
#   -1,
#   '61652',
#   -1,
#   -1,
#   -1,
#   '1622 ',
#   'Australia/Oceania',
#   '16',
#   -1,
#   -1,
#   '1233',
#   -1,
#   '8,631'],
#  ['Total:',
#   '643105643',
#   209901.0,
#   '6626087',
#   396.0,
#   '622217754',
#   193233.0,
#   '14261802',
#   '36119',
#   '82504.5',
#   '850.1',
#   -1,
#   -1,
#   -1,
#   'All',
#   '\n',
#   -1,
#   -1,
#   -1,
#   -1,
#   -1]]

# %%
df = pd.DataFrame(all_data)
df.drop([15,16,17,18,19,20] , inplace = True,axis = 1)
df.head()
# Out:
#         0          1         2                                        3   \
# 0    World  643105643  209901.0                                  6626087
# 1      USA  100209101    4996.0  1102668
# 2    India   44670438     421.0   530586
# 3   France   37348839   14204.0   158163
# 4  Germany   36205405      -1.0   156613
#
#       4          5         6         7      8       9      10          11  \
# 0  396.0  622217754  193233.0  14261802  36119   82504  850.1          -1
# 1    2.0   97751014   18915.0   1355419   2745  299306   3293  1137483003
# 2   12.0   44132433     481.0      7419    698   31757    377   903809991
# 3   -1.0   36655222    3768.0    535454    869  569476   2412   271490188
# 4   -1.0   35359000   11600.0    689792   1406  431615   1867   122332384
#
#         12           13             14
# 0       -1           -1            All
# 1  3397447   334805269   North America
# 2   642535  1406631776            Asia
# 3  4139547    65584518          Europe
# 4  1458359    83883596          Europe

# %%
column_labels = ["Country","Total Cases","New Cases","Total Deaths","New Deaths","Total Recovered","New Recovered","Active Cases","Serious/Critical","Total Cases/1M","Deaths/1M","Total Tests","Test/1M","Population","Continent"]
df.columns = column_labels

# %%
df.head()
# Out:
#    Country Total Cases  New Cases                             Total Deaths  \
# 0    World   643105643   209901.0                                  6626087
# 1      USA   100209101     4996.0  1102668
# 2    India    44670438      421.0   530586
# 3   France    37348839    14204.0   158163
# 4  Germany    36205405       -1.0   156613
#
#    New Deaths Total Recovered  New Recovered Active Cases Serious/Critical  \
# 0       396.0       622217754       193233.0     14261802            36119
# 1         2.0        97751014        18915.0      1355419             2745
# 2        12.0        44132433          481.0         7419              698
# 3        -1.0        36655222         3768.0       535454              869
# 4        -1.0        35359000        11600.0       689792             1406
#
#   Total Cases/1M Deaths/1M Total Tests  Test/1M   Population      Continent
# 0          82504     850.1          -1       -1           -1            All
# 1         299306      3293  1137483003  3397447   334805269   North America
# 2          31757       377   903809991   642535  1406631776            Asia
# 3         569476      2412   271490188  4139547    65584518          Europe
# 4         431615      1867   122332384  1458359    83883596          Europe

# %%
for label in df.columns:
  if label != 'Country' and label != "Continent":
      df[label] = pd.to_numeric(df[label])

# %%
df["%Inc Cases"] = df["New Cases"]/df["Total Cases"]*100
df["%Inc Deaths"] = df["New Deaths"]/df["Total Deaths"]*100
df["%Inc Recovered"] = df["New Recovered"]/df["Total Recovered"]*100

# %%
df.head()
# Out:
#    Country  Total Cases  New Cases  Total Deaths  New Deaths  Total Recovered  \
# 0    World    643105643   209901.0       6626087       396.0        622217754
# 1      USA    100209101     4996.0       1102668         2.0         97751014
# 2    India     44670438      421.0        530586        12.0         44132433
# 3   France     37348839    14204.0        158163        -1.0         36655222
# 4  Germany     36205405       -1.0        156613        -1.0         35359000
#
#    New Recovered  Active Cases  Serious/Critical  Total Cases/1M  Deaths/1M  \
# 0       193233.0      14261802             36119         82504.0      850.1
# 1        18915.0       1355419              2745        299306.0     3293.0
# 2          481.0          7419               698         31757.0      377.0
# 3         3768.0        535454               869        569476.0     2412.0
# 4        11600.0        689792              1406        431615.0     1867.0
#
#    Total Tests  Test/1M  Population      Continent  %Inc Cases  %Inc Deaths  \
# 0           -1       -1          -1            All    0.032639     0.005976
# 1   1137483003  3397447   334805269  North America    0.004986     0.000181
# 2    903809991   642535  1406631776           Asia    0.000942     0.002262
# 3    271490188  4139547    65584518         Europe    0.038031    -0.000632
# 4    122332384  1458359    83883596         Europe   -0.000003    -0.000639
#
#    %Inc Recovered
# 0        0.031056
# 1        0.019350
# 2        0.001090
# 3        0.010280
# 4        0.032806

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**

# %%
cases = df[["Total Recovered", "Active Cases", "Total Deaths"]].loc[0]
cases_df = pd.DataFrame(cases).reset_index()
cases_df.columns = ["Type" , "Total"]

cases_df["Percentage"] = np.round(100*cases_df['Total']/np.sum(cases_df["Total"]),2)
cases_df["Virus"] = ["COVID-19" for i in range(len(cases_df))]

fig = px.bar(cases_df, x = "Virus", y = "Percentage", color = "Type", hover_data=["Total"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="29c71803-6210-4e16-8d11-5853649c545b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("29c71803-6210-4e16-8d11-5853649c545b")) {                    Plotly.newPlot(                        "29c71803-6210-4e16-8d11-5853649c545b",                        [{"alignmentgroup":"True","customdata":[[622217754]],"hovertemplate":"Type=Total Recovered<br>Virus=%{x}<br>Percentage=%{y}<br>Total=%{customdata[0]}<extra></extra>","legendgroup":"Total Recovered","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Total Recovered","offsetgroup":"Total Recovered","orientation":"v","showlegend":true,"textposition":"auto","x":["COVID-19"],"xaxis":"x","y":[96.75],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[14261802]],"hovertemplate":"Type=Active Cases<br>Virus=%{x}<br>Percentage=%{y}<br>Total=%{customdata[0]}<extra></extra>","legendgroup":"Active Cases","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Active Cases","offsetgroup":"Active Cases","orientation":"v","showlegend":true,"textposition":"auto","x":["COVID-19"],"xaxis":"x","y":[2.22],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[6626087]],"hovertemplate":"Type=Total Deaths<br>Virus=%{x}<br>Percentage=%{y}<br>Total=%{customdata[0]}<extra></extra>","legendgroup":"Total Deaths","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Total Deaths","offsetgroup":"Total Deaths","orientation":"v","showlegend":true,"textposition":"auto","x":["COVID-19"],"xaxis":"x","y":[1.03],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.33333 ...

# %%
cases = df[["New Cases", "New Recovered", "New Deaths"]].loc[0]
cases_df = pd.DataFrame(cases).reset_index()
cases_df.columns = ["Type" , "Total"]

cases_df["Percentage"] = np.round(100*cases_df['Total']/np.sum(cases_df["Total"]),2)
cases_df["Virus"] = ["COVID-19" for i in range(len(cases_df))]

fig = px.bar(cases_df, x = "Virus", y = "Percentage", color = "Type", hover_data=["Total"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="34ad7797-d928-4c3e-89f1-5bfda26929d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34ad7797-d928-4c3e-89f1-5bfda26929d3")) {                    Plotly.newPlot(                        "34ad7797-d928-4c3e-89f1-5bfda26929d3",                        [{"alignmentgroup":"True","customdata":[[209901.0]],"hovertemplate":"Type=New Cases<br>Virus=%{x}<br>Percentage=%{y}<br>Total=%{customdata[0]}<extra></extra>","legendgroup":"New Cases","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"New Cases","offsetgroup":"New Cases","orientation":"v","showlegend":true,"textposition":"auto","x":["COVID-19"],"xaxis":"x","y":[52.02],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[193233.0]],"hovertemplate":"Type=New Recovered<br>Virus=%{x}<br>Percentage=%{y}<br>Total=%{customdata[0]}<extra></extra>","legendgroup":"New Recovered","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"New Recovered","offsetgroup":"New Recovered","orientation":"v","showlegend":true,"textposition":"auto","x":["COVID-19"],"xaxis":"x","y":[47.89],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[396.0]],"hovertemplate":"Type=New Deaths<br>Virus=%{x}<br>Percentage=%{y}<br>Total=%{customdata[0]}<extra></extra>","legendgroup":"New Deaths","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"New Deaths","offsetgroup":"New Deaths","orientation":"v","showlegend":true,"textposition":"auto","x":["COVID-19"],"xaxis":"x","y":[0.1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444 ...

# %%
per = np.round(df[["%Inc Cases", "%Inc Deaths", "%Inc Recovered"]].loc[0], 2)

per_df = pd.DataFrame(per)
per_df.columns = ["Percentage"]

fig = go.Figure()

fig.add_trace(go.Bar(x = per_df.index , y = per_df["Percentage"], marker_color = ["red","blue","green"]))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="38577b2a-e706-4463-af23-12ac2c3ffcf7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38577b2a-e706-4463-af23-12ac2c3ffcf7")) {                    Plotly.newPlot(                        "38577b2a-e706-4463-af23-12ac2c3ffcf7",                        [{"marker":{"color":["red","blue","green"]},"x":["%Inc Cases","%Inc Deaths","%Inc Recovered"],"y":[0.03,0.01,0.03],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"ma ...

# %% [markdown]
# **CONTINENT**

# %%
continent_df = df.groupby("Continent").sum().drop("All")
continent_df = continent_df.reset_index()
continent_df
# Out:
#            Continent  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0             Africa     12679748      368.0        257812       -55.0
# 1               Asia    175158848   159268.0       1388159       248.0
# 2  Australia/Oceania     12864664     6175.0         22029       -13.0
# 3             Europe    236828403    24536.0       1955924        29.0
# 4      North America    118728245     5144.0       1560777       -34.0
# 5      South America     64790842    11990.0       1334559        27.0
#
#    Total Recovered  New Recovered  Active Cases  Serious/Critical  \
# 0         10877760          411.0        339119               814
# 1        167335878       103805.0       6219103              9372
# 2         12518029         3062.0        226277               113
# 3        231035330        54319.0       3557843              7624
# 4        114070483        22210.0       2219017              7890
# 5         62991252         8184.0        385195             10129
#
#    Total Cases/1M  Deaths/1M  Total Tests    Test/1M  Population  %Inc Cases  \
# 0       2360160.0    18045.0    109188842   10730181  1402212660    0.212612
# 1       6828977.0    32048.0   1998016161   88765856  3151332728    1.343188
# 2       3599683.0     8207.0     88293817   20348041    43469030   16.580254
# 3      18020573.0   121136.0   2791657942  209901879   747543038    0.301500
# 4       8600341.0    56988.0   1271831670   99144087   598140916   -0.274337
# 5       1951171.0    32587.0    238797449   11276984   437690904    0.161565
#
#    %Inc Deaths  %Inc Recovered
# 0    86.136432      -49.865554
# 1   -23.504679        1.201522
# 2   -64.130085      100.910210
# 3   -10.902569        0.884146
# 4  -163.385584       -0.286476
# 5    -0.395900        0.197124

# %%
def continent_visualization(vis_list):
    for label in vis_list:
        c_df = continent_df[["Continent", label]]
        c_df["Percentage"] = np.round(100*c_df[label]/np.sum(c_df[label]),2)
        c_df["Virus"] = ["Covid-19" for i in range(len(c_df))]

        fig = px.bar(c_df, x = "Virus", y = "Percentage", color = "Continent", hover_data=[label])
        fig.update_layout(title = {"text": f"{label}"})
        fig.show()
        gc.collect()

# %%
cases_list = ["Total Cases", "Active Cases", "New Cases", "Serious/Critical", "Total Cases/1M"]

deaths_list = ["Total Deaths","New Deaths","Deaths/1M"]

recovered_list = ["Total Recovered","New Recovered","%Inc Recovered"]

# %%
continent_visualization(cases_list)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0f2a17aa-ae4f-4e1d-a1ee-ad617da95607" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f2a17aa-ae4f-4e1d-a1ee-ad617da95607")) {                    Plotly.newPlot(                        "0f2a17aa-ae4f-4e1d-a1ee-ad617da95607",                        [{"alignmentgroup":"True","customdata":[[12679748]],"hovertemplate":"Continent=Africa<br>Virus=%{x}<br>Percentage=%{y}<br>Total Cases=%{customdata[0]}<extra></extra>","legendgroup":"Africa","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Africa","offsetgroup":"Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[2.04],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[175158848]],"hovertemplate":"Continent=Asia<br>Virus=%{x}<br>Percentage=%{y}<br>Total Cases=%{customdata[0]}<extra></extra>","legendgroup":"Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[28.2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[12864664]],"hovertemplate":"Continent=Australia/Oceania<br>Virus=%{x}<br>Percentage=%{y}<br>Total Cases=%{customdata[0]}<extra></extra>","legendgroup":"Australia/Oceania","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Australia/Oceania","offsetgroup":"Australia/Oceania","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[2.07],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[236828403]],"hovertemplate":"Continent=Europe<br>Virus=%{x}<br>Percentage=%{y}<br>Total Cases=%{customdata[0]}<extra></extra>","legendgroup":"Europe","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Europe","offsetgroup":"Europe","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[38.13],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[118728245]],"hovertemplate":"Continent=North America<br>Virus=%{x}<br>Percentage=%{y}<br>Total Cases=%{customdata[0]}<extra></extra>","legendgroup":"North America","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[19.12],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[64790842]],"hovertemplate":"Continent=South America<br>Virus=%{x}<br>Percentage=%{y}<br>Total Cases=%{customdata[0]}<extra></extra>","legendgroup":"South America","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South America","offsetgroup":"South America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[10.43],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6064dee0-7b60-41a1-a3a1-e3aae6db75dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6064dee0-7b60-41a1-a3a1-e3aae6db75dc")) {                    Plotly.newPlot(                        "6064dee0-7b60-41a1-a3a1-e3aae6db75dc",                        [{"alignmentgroup":"True","customdata":[[339119]],"hovertemplate":"Continent=Africa<br>Virus=%{x}<br>Percentage=%{y}<br>Active Cases=%{customdata[0]}<extra></extra>","legendgroup":"Africa","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Africa","offsetgroup":"Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[2.62],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[6219103]],"hovertemplate":"Continent=Asia<br>Virus=%{x}<br>Percentage=%{y}<br>Active Cases=%{customdata[0]}<extra></extra>","legendgroup":"Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[48.04],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[226277]],"hovertemplate":"Continent=Australia/Oceania<br>Virus=%{x}<br>Percentage=%{y}<br>Active Cases=%{customdata[0]}<extra></extra>","legendgroup":"Australia/Oceania","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Australia/Oceania","offsetgroup":"Australia/Oceania","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[1.75],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[3557843]],"hovertemplate":"Continent=Europe<br>Virus=%{x}<br>Percentage=%{y}<br>Active Cases=%{customdata[0]}<extra></extra>","legendgroup":"Europe","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Europe","offsetgroup":"Europe","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[27.48],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[2219017]],"hovertemplate":"Continent=North America<br>Virus=%{x}<br>Percentage=%{y}<br>Active Cases=%{customdata[0]}<extra></extra>","legendgroup":"North America","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[17.14],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[385195]],"hovertemplate":"Continent=South America<br>Virus=%{x}<br>Percentage=%{y}<br>Active Cases=%{customdata[0]}<extra></extra>","legendgroup":"South America","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South America","offsetgroup":"South America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[2.98],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"# ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f4ecffcb-a809-4215-809f-51cddbbabbce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f4ecffcb-a809-4215-809f-51cddbbabbce")) {                    Plotly.newPlot(                        "f4ecffcb-a809-4215-809f-51cddbbabbce",                        [{"alignmentgroup":"True","customdata":[[368.0]],"hovertemplate":"Continent=Africa<br>Virus=%{x}<br>Percentage=%{y}<br>New Cases=%{customdata[0]}<extra></extra>","legendgroup":"Africa","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Africa","offsetgroup":"Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.18],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[159268.0]],"hovertemplate":"Continent=Asia<br>Virus=%{x}<br>Percentage=%{y}<br>New Cases=%{customdata[0]}<extra></extra>","legendgroup":"Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[76.76],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[6175.0]],"hovertemplate":"Continent=Australia/Oceania<br>Virus=%{x}<br>Percentage=%{y}<br>New Cases=%{customdata[0]}<extra></extra>","legendgroup":"Australia/Oceania","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Australia/Oceania","offsetgroup":"Australia/Oceania","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[2.98],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[24536.0]],"hovertemplate":"Continent=Europe<br>Virus=%{x}<br>Percentage=%{y}<br>New Cases=%{customdata[0]}<extra></extra>","legendgroup":"Europe","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Europe","offsetgroup":"Europe","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[11.83],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[5144.0]],"hovertemplate":"Continent=North America<br>Virus=%{x}<br>Percentage=%{y}<br>New Cases=%{customdata[0]}<extra></extra>","legendgroup":"North America","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[2.48],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[11990.0]],"hovertemplate":"Continent=South America<br>Virus=%{x}<br>Percentage=%{y}<br>New Cases=%{customdata[0]}<extra></extra>","legendgroup":"South America","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South America","offsetgroup":"South America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[5.78],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4a583fdb-0e97-4470-82fe-629f035efa2b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a583fdb-0e97-4470-82fe-629f035efa2b")) {                    Plotly.newPlot(                        "4a583fdb-0e97-4470-82fe-629f035efa2b",                        [{"alignmentgroup":"True","customdata":[[814]],"hovertemplate":"Continent=Africa<br>Virus=%{x}<br>Percentage=%{y}<br>Serious/Critical=%{customdata[0]}<extra></extra>","legendgroup":"Africa","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Africa","offsetgroup":"Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[2.26],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[9372]],"hovertemplate":"Continent=Asia<br>Virus=%{x}<br>Percentage=%{y}<br>Serious/Critical=%{customdata[0]}<extra></extra>","legendgroup":"Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[26.08],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[113]],"hovertemplate":"Continent=Australia/Oceania<br>Virus=%{x}<br>Percentage=%{y}<br>Serious/Critical=%{customdata[0]}<extra></extra>","legendgroup":"Australia/Oceania","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Australia/Oceania","offsetgroup":"Australia/Oceania","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.31],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[7624]],"hovertemplate":"Continent=Europe<br>Virus=%{x}<br>Percentage=%{y}<br>Serious/Critical=%{customdata[0]}<extra></extra>","legendgroup":"Europe","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Europe","offsetgroup":"Europe","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[21.21],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[7890]],"hovertemplate":"Continent=North America<br>Virus=%{x}<br>Percentage=%{y}<br>Serious/Critical=%{customdata[0]}<extra></extra>","legendgroup":"North America","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[21.95],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[10129]],"hovertemplate":"Continent=South America<br>Virus=%{x}<br>Percentage=%{y}<br>Serious/Critical=%{customdata[0]}<extra></extra>","legendgroup":"South America","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South America","offsetgroup":"South America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[28.18],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="682925f6-342e-4475-8db9-4988fbe7685e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("682925f6-342e-4475-8db9-4988fbe7685e")) {                    Plotly.newPlot(                        "682925f6-342e-4475-8db9-4988fbe7685e",                        [{"alignmentgroup":"True","customdata":[[2360160.0]],"hovertemplate":"Continent=Africa<br>Virus=%{x}<br>Percentage=%{y}<br>Total Cases/1M=%{customdata[0]}<extra></extra>","legendgroup":"Africa","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Africa","offsetgroup":"Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[5.71],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[6828977.0]],"hovertemplate":"Continent=Asia<br>Virus=%{x}<br>Percentage=%{y}<br>Total Cases/1M=%{customdata[0]}<extra></extra>","legendgroup":"Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[16.51],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[3599683.0]],"hovertemplate":"Continent=Australia/Oceania<br>Virus=%{x}<br>Percentage=%{y}<br>Total Cases/1M=%{customdata[0]}<extra></extra>","legendgroup":"Australia/Oceania","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Australia/Oceania","offsetgroup":"Australia/Oceania","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[8.7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[18020573.0]],"hovertemplate":"Continent=Europe<br>Virus=%{x}<br>Percentage=%{y}<br>Total Cases/1M=%{customdata[0]}<extra></extra>","legendgroup":"Europe","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Europe","offsetgroup":"Europe","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[43.57],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[8600341.0]],"hovertemplate":"Continent=North America<br>Virus=%{x}<br>Percentage=%{y}<br>Total Cases/1M=%{customdata[0]}<extra></extra>","legendgroup":"North America","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[20.79],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[1951171.0]],"hovertemplate":"Continent=South America<br>Virus=%{x}<br>Percentage=%{y}<br>Total Cases/1M=%{customdata[0]}<extra></extra>","legendgroup":"South America","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South America","offsetgroup":"South America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[4.72],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c17 ...

# %% [markdown]
# **COUNTRIES**

# %%
df = df.drop([len(df)-1])
country_df = df.drop([0])

country_df
# Out:
#                Country  Total Cases  New Cases  Total Deaths  New Deaths  \
# 1                  USA    100209101     4996.0       1102668         2.0
# 2                India     44670438      421.0        530586        12.0
# 3               France     37348839    14204.0        158163        -1.0
# 4              Germany     36205405       -1.0        156613        -1.0
# 5               Brazil     35064320     4300.0        689003         9.0
# ..                 ...          ...        ...           ...         ...
# 216       Saint Helena         1806       -1.0            -1        -1.0
# 217         Montserrat         1403       -1.0             8        -1.0
# 218              Macao          796       -1.0             6        -1.0
# 219  Wallis and Futuna          761       -1.0             7        -1.0
# 220               Niue          100        2.0            -1        -1.0
#
#      Total Recovered  New Recovered  Active Cases  Serious/Critical  \
# 1           97751014        18915.0       1355419              2745
# 2           44132433          481.0          7419               698
# 3           36655222         3768.0        535454               869
# 4           35359000        11600.0        689792              1406
# 5           34167667           -1.0        207650              8318
# ..               ...            ...           ...               ...
# 216                2           -1.0          1804                -1
# 217             1376           -1.0            19                -1
# 218              789           -1.0             1                -1
# 219              438           -1.0           316                -1
# 220               86            1.0            14                -1
#
#      Total Cases/1M  Deaths/1M  Total Tests  Test/1M  Population  \
# 1          299306.0     3293.0   1137483003  3397447   334805269
# 2           31757.0      377.0    903809991   642535  1406631776
# 3          569476.0     2412.0    271490188  4139547    65584518
# 4          431615.0     1867.0    122332384  1458359    83883596
# 5          162822.0     3199.0     63776166   296146   215353593
# ..              ...        ...          ...      ...         ...
# 216        295339.0       -1.0           -1       -1        6115
# 217        282578.0     1611.0        17762  3577442        4965
# 218          1193.0        9.0         7850    11760      667490
# 219         69295.0      637.0        20508  1867419       10982
# 220         61652.0       -1.0           -1       -1        1622
#
#              Continent  %Inc Cases  %Inc Deaths  %Inc Recovered
# 1        North America    0.004986     0.000181        0.019350
# 2                 Asia    0.000942     0.002262        0.001090
# 3               Europe    0.038031    -0.000632        0.010280
# 4               Europe   -0.000003    -0.000639        0.032806
# 5        South America    0.012263     0.001306       -0.000003
# ..                 ...         ...          ...             ...
# 216             Africa   -0.055371   100.000000      -50.000000
# 217      North America   -0.071276   -12.500000       -0.072674
# 218               Asia   -0.125628   -16.666667       -0.126743
# 219  Australia/Oceania   -0.131406   -14.285714       -0.228311
# 220  Australia/Oceania    2.000000   100.000000        1.162791
#
# [220 rows x 18 columns]

# %%
LOOK_AT = 5
country = country_df.columns[1:14]

fig = go.Figure()
c = 0
for i in country_df.index:
    if c < LOOK_AT:
        fig.add_trace(go.Bar(name = country_df['Country'][i], x = country, y = country_df.loc[i][1:14])) 
    else:
        break
    c += 1

fig.update_layout(title = {"text":f'top {LOOK_AT} countries affected'}, yaxis_type = "log")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3cdc8c28-626a-4c63-af3f-75b7c031ab7a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3cdc8c28-626a-4c63-af3f-75b7c031ab7a")) {                    Plotly.newPlot(                        "3cdc8c28-626a-4c63-af3f-75b7c031ab7a",                        [{"name":"USA","x":["Total Cases","New Cases","Total Deaths","New Deaths","Total Recovered","New Recovered","Active Cases","Serious/Critical","Total Cases/1M","Deaths/1M","Total Tests","Test/1M","Population"],"y":[100209101,4996.0,1102668,2.0,97751014,18915.0,1355419,2745,299306.0,3293.0,1137483003,3397447,334805269],"type":"bar"},{"name":"India","x":["Total Cases","New Cases","Total Deaths","New Deaths","Total Recovered","New Recovered","Active Cases","Serious/Critical","Total Cases/1M","Deaths/1M","Total Tests","Test/1M","Population"],"y":[44670438,421.0,530586,12.0,44132433,481.0,7419,698,31757.0,377.0,903809991,642535,1406631776],"type":"bar"},{"name":"France","x":["Total Cases","New Cases","Total Deaths","New Deaths","Total Recovered","New Recovered","Active Cases","Serious/Critical","Total Cases/1M","Deaths/1M","Total Tests","Test/1M","Population"],"y":[37348839,14204.0,158163,-1.0,36655222,3768.0,535454,869,569476.0,2412.0,271490188,4139547,65584518],"type":"bar"},{"name":"Germany","x":["Total Cases","New Cases","Total Deaths","New Deaths","Total Recovered","New Recovered","Active Cases","Serious/Critical","Total Cases/1M","Deaths/1M","Total Tests","Test/1M","Population"],"y":[36205405,-1.0,156613,-1.0,35359000,11600.0,689792,1406,431615.0,1867.0,122332384,1458359,83883596],"type":"bar"},{"name":"Brazil","x":["Total Cases","New Cases","Total Deaths","New Deaths","Total Recovered","New Recovered","Active Cases","Serious/Critical","Total Cases/1M","Deaths/1M","Total Tests","Test/1M","Population"],"y":[35064320,4300.0,689003,9.0,34167667,-1.0,207650,8318,162822.0,3199.0,63776166,296146,215353593],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666666666666 ...
